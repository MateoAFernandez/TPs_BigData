# %% [markdown]
# # Curso de Big Data
#
# ## Trabajo Práctico 1 - Parte 2
#
# ### Grupo: Armas Braithwaite, Fernández, Menta, Vargas Ochuza

# %% [markdown]
# ### Reglas de formato y presentación
# - El trabajo debe estar bien comentado (utilizando #) para que el código sea fácil de entender por sus compañeros y profesores.
#
# - El mismo debe ser completado en este Jupyter Notebook y entregado como tal, es decir en un archivo .ipynb

# %% [markdown]
# ### Fecha de entrega:
# Miércoles 4 de octubre a las 23:59hs

# %% [markdown]
# ### Modalidad de entrega
# - Al finalizar el trabajo práctico deben hacer un último <i>commit</i> en su repositorio de GitHub con el mensaje “Entrega final del tp”.
# - Asegurense de haber creado una carpeta llamada TP1. Este Jupyter Notebook y el correspondiente al TP1 - Parte 1 deben estar dentro de esa carpeta.
# - También deben completar el link de su repositorio -para que pueda ser clonado y corregido- en la siguiente google sheet: https://docs.google.com/spreadsheets/d/11nJY1Frgla45sTgsPiSeOZM9iBM-XRWh/edit?usp=sharing&ouid=105815768529474116534&rtpof=true&sd=true
# - La última versión en el repositorio es la que será evaluada. Por lo que es importante que:
#     - No completen la google sheet hasta no haber terminado y estar seguros de que han hecho el <i>commit y push</i> a la versión final que quieren entregar. Debido a que se pueden tomar hasta 3 días de extensión a lo largo del curso, no se  corregirán sus tareas hasta no ver el link en la google sheet.
#     - No hagan nuevos <i>push</i> despues de haber entregado su versión final. Esto generaría confusión acerca de que versión es la que quieren que se les corrija.

# %% [markdown]
# #### Ejercicio 1
# Usando la API de Mercado Libre, obtener los ítems de una consulta de búsqueda. Pueden buscar cualquier producto de su interés.

# %%
# Importamos los módulos necesarios para trabajar
import requests
import matplotlib.pyplot as plt

# %%
# Nuestro producto de interés será Protector Solar
buscar = "Protector Solar"

# Seguimos el formato que requiere la API donde adicionalmente indicamos que es MercadoLibre Argentina
url = "https://api.mercadolibre.com/sites/{}/search?q={}".format("MLA", buscar.replace(" ", "%20"))

# Hacemos el 'request' y obtenemos la 'response'
response = requests.request("GET", url)
print(response) 

# Vemos el texto
response.text
# Out:
# <Response [200]>
# '{"site_id":"MLA","country_default_time_zone":"GMT-03:00","query":"Protector Solar","paging":{"total":2902,"primary_results":1000,"offset":0,"limit":50},"results":[{"id":"MLA901447311","title":"Protector Solar Dermaglós Fps 50 Fps 50 En Emulsión De 250 Ml","condition":"new","thumbnail_id":"641809-MLA44740405275_012021","catalog_product_id":"MLA16048315","listing_type_id":"gold_special","permalink":"https://www.mercadolibre.com.ar/protector-solar-dermaglos-fps-50-fps-50-en-emulsion-de-250-ml/p/MLA16048315","buying_mode":"buy_it_now","site_id":"MLA","category_id":"MLA392400","domain_id":"MLA-SUNSCREENS","thumbnail":"http://http2.mlstatic.com/D_641809-MLA44740405275_012021-I.jpg","currency_id":"ARS","order_backend":1,"price":8019,"original_price":10027,"sale_price":null,"sold_quantity":500,"available_quantity":500,"official_store_id":1859,"official_store_name":"Farmacias Selma","use_thumbnail_id":true,"accepts_mercadopago":true,"tags":["loyalty_discount_eligible","brand_verified","supermarket_eligible","good_quality_picture","standard_price_by_channel","good_quality_thumbnail","immediate_payment","cart_eligible","best_seller_candidate","shipping_guaranteed"],"shipping":{"store_pick_up":false,"free_shipping":false,"logistic_type":"fulfillment","mode":"me2","tags":["fulfillment","self_service_out"],"benefits":null,"promise":null},"stop_time":"2040-12-12T04:00:00.000Z","seller":{"id":377840555,"nickname":"FARMACIA SELMA","car_dealer":false,"real_estate_agency":false,"_":false,"registration_date":"2018-11-14T13:58:49.000-04:00","tags":["brand","large_seller","eshop","mshops","credits_profile","messages_as_seller"],"car_dealer_logo":"","permalink":"http://perfil.mercadolibre.com.ar/FARMACIA+SELMA","seller_reputation":{"level_id":"5_green","power_seller_status":"platinum","transactions":{"canceled":22715,"completed":578191,"period":"historic","ratings":{"negative":0.06,"neutral":0.02,"positive":0.92},"total":600906},"metrics":{"sales":{"period":"60 days","completed":132156},"claims":{"period":"60 days","rate":0.0026,"value":364},"delayed_handling_time":{"period":"60 days","rate":0.0015,"value":205},"cancellations":{"period":"60 days","rate":0.002,"value":286}}},"eshop":{"eshop_id":335554,"seller":377840555,"nick_name":"FARMACIA SELMA","eshop_status_id":1,"site_id":"MLA","eshop_experience":0,"eshop_rubro":null,"eshop_locations":[],"eshop_logo_url":"http://http2.mlstatic.com/eshops-logo/377840555ve918d7.png"}},"seller_address":{"comment":"","address_line":"","id":null,"latitude":null,"longitude":null,"country":{"id":"AR","name":"Argentina"},"state":{"id":"AR-B","name":"Buenos Aires"},"city":{"id":null,"name":"Olivos"}},"address":{"state_id":"AR-B","state_name":"Buenos Aires","city_id":null,"city_name":"Olivos"},"attributes":[{"id":"BRAND","name":"Marca","value_id":"968610","value_name":"Dermaglós","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":null,"values":[{"id":"968610","name":"Dermaglós","struct":null,"source":1}],"source":1,"value_type":"string"},{"id":"ITEM_CONDITION","name":"Condición del ítem","value_id":"2230284","value_name":"Nuevo","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":null,"values":[{"id":"2230284","name":"Nuevo","struct":null,"source":1}],"source":1,"value_type":"list"},{"id":"LINE","name":"Línea","value_id":"2124246","value_name":"Solar","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":null,"values":[{"id":"2124246","name":"Solar","struct":null,"source":4709228965570453}],"source":4709228965570453,"value_type":"string"},{"id":"MODEL","name":"Modelo","value_id":"8868325","value_name":"FPS 50","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":null,"values":[{"id":"8868325","name":"FPS 50","struct":null,"source":1}],"source":1,"value_type":"string"},{"id":"NET_VOLUME","name":"Volumen neto","value_id":"127299","value_name":"250 mL","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":{"n ...

# %%
# Guardamos el resultado en un diccionario, utilizamos Json debido a que es muy amigable para hacer estas tareas
# y le brinda una estructura util
data = response.json()

# obtenemos un diccionario denominado 'data'
data
# Out:
# {'site_id': 'MLA',
#  'country_default_time_zone': 'GMT-03:00',
#  'query': 'Protector Solar',
#  'paging': {'total': 2902, 'primary_results': 1000, 'offset': 0, 'limit': 50},
#  'results': [{'id': 'MLA901447311',
#    'title': 'Protector Solar Dermaglós Fps 50 Fps 50 En Emulsión De 250 Ml',
#    'condition': 'new',
#    'thumbnail_id': '641809-MLA44740405275_012021',
#    'catalog_product_id': 'MLA16048315',
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://www.mercadolibre.com.ar/protector-solar-dermaglos-fps-50-fps-50-en-emulsion-de-250-ml/p/MLA16048315',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA392400',
#    'domain_id': 'MLA-SUNSCREENS',
#    'thumbnail': 'http://http2.mlstatic.com/D_641809-MLA44740405275_012021-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 1,
#    'price': 8019,
#    'original_price': 10027,
#    'sale_price': None,
#    'sold_quantity': 500,
#    'available_quantity': 500,
#    'official_store_id': 1859,
#    'official_store_name': 'Farmacias Selma',
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'tags': ['loyalty_discount_eligible',
#     'brand_verified',
#     'supermarket_eligible',
#     'good_quality_picture',
#     'standard_price_by_channel',
#     'good_quality_thumbnail',
#     'immediate_payment',
#     'cart_eligible',
#     'best_seller_candidate',
#     'shipping_guaranteed'],
#    'shipping': {'store_pick_up': False,
#     'free_shipping': False,
#     'logistic_type': 'fulfillment',
#     'mode': 'me2',
#     'tags': ['fulfillment', 'self_service_out'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2040-12-12T04:00:00.000Z',
#    'seller': {'id': 377840555,
#     'nickname': 'FARMACIA SELMA',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     '_': False,
#     'registration_date': '2018-11-14T13:58:49.000-04:00',
#     'tags': ['brand',
#      'large_seller',
#      'eshop',
#      'mshops',
#      'credits_profile',
#      'messages_as_seller'],
#     'car_dealer_logo': '',
#     'permalink': 'http://perfil.mercadolibre.com.ar/FARMACIA+SELMA',
#     'seller_reputation': {'level_id': '5_green',
#      'power_seller_status': 'platinum',
#      'transactions': {'canceled': 22715,
#       'completed': 578191,
#       'period': 'historic',
#       'ratings': {'negative': 0.06, 'neutral': 0.02, 'positive': 0.92},
#       'total': 600906},
#      'metrics': {'sales': {'period': '60 days', 'completed': 132156},
#       'claims': {'period': '60 days', 'rate': 0.0026, 'value': 364},
#       'delayed_handling_time': {'period': '60 days',
#        'rate': 0.0015,
#        'value': 205},
#       'cancellations': {'period': '60 days', 'rate': 0.002, 'value': 286}}},
#     'eshop': {'eshop_id': 335554,
#      'seller': 377840555,
#      'nick_name': 'FARMACIA SELMA',
#      'eshop_status_id': 1,
#      'site_id': 'MLA',
#      'eshop_experience': 0,
#      'eshop_rubro': None,
#      'eshop_locations': [],
#      'eshop_logo_url': 'http://http2.mlstatic.com/eshops-logo/377840555ve918d7.png'}},
#    'seller_address': {'comment': '',
#     'address_line': '',
#     'id': None,
#     'latitude': None,
#     'longitude': None,
#     'country': {'id': 'AR', 'name': 'Argentina'},
#     'state': {'id': 'AR-B', 'name': 'Buenos Aires'},
#     'city': {'id': None, 'name': 'Olivos'}},
#    'address': {'state_id': 'AR-B',
#     'state_name': 'Buenos Aires',
#     'city_id': None,
#     'city_name': 'Olivos'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '968610',
#      'value_name': 'Dermaglós',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '968610',
#        'name': 'Dermaglós',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'LINE',
#      'name': 'Línea',
#      'value_id': '2124246',
#      'value_name': 'Solar',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2124246',
#        'name': 'Solar',
#        'struct': None,
#        'source': 4709228965570453}],
#      'source': 4709228965570453,
#      'value_type': 'string'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '8868325',
#      'value_name': 'FPS 50',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '8868325',
#        'name': 'FPS 50',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'NET_VOLUME',
#      'name': 'Volumen neto',
#      'value_id': '127299',
#      'value_name': '250 mL',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 250, 'unit': 'mL'},
#      'values': [{'id': '127299',
#        'name': '250 mL',
#        'struct': {'number': 250, 'unit': 'mL'},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_LENGTH',
#      'name': 'Largo del paquete',
#      'value_id': None,
#      'value_name': '7 cm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 7, 'unit': 'cm'},
#      'values': [{'id': None,
#        'name': '7 cm',
#        'struct': {'number': 7, 'unit': 'cm'},
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_WEIGHT',
#      'name': 'Peso del paquete',
#      'value_id': None,
#      'value_name': '220 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 220, 'unit': 'g'},
#      'values': [{'id': None,
#        'name': '220 g',
#        'struct': {'number': 220, 'unit': 'g'},
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'number_unit'},
#     {'id': 'SALE_FORMAT',
#      'name': 'Formato de venta',
#      'value_id': '1359391',
#      'value_name': 'Unidad',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '1359391',
#        'name': 'Unidad',
#        'struct': None,
#        'source': 4709228965570453}],
#      'source': 4709228965570453,
#      'value_type': 'list'},
#     {'id': 'UNITS_PER_PACK',
#      'name': 'Unidades por pack',
#      'value_id': '2726554',
#      'value_name': '1',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2726554',
#        'name': '1',
#        'struct': None,
#        'source': 4709228965570453}],
#      'source': 4709228965570453,
#      'value_type': 'number'}],
#    'installments': {'quantity': 12,
#     'amount': 1507.57,
#     'rate': 125.6,
#     'currency_id': 'ARS'},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': 'CCKD15286'},
#   {'id': 'MLA1150055201',
#    'title': 'Dermaglos Facial Fps50 Efecto Seco Invisible X 50 Gr',
#    'condition': 'new',
#    'thumbnail_id': '701169-MLA50107987130_052022',
#    'catalog_product_id': 'MLA19504472',
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://www.mercadolibre.com.ar/dermaglos-facial-fps50-efecto-seco-invisible-x-50-gr/p/MLA19504472',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA392400',
#    'domain_id': 'MLA-SUNSCREENS',
#    'thumbnail': 'http://http2.mlstatic.com/D_701169-MLA50107987130_052022-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 2,
#    'price': 8846,
#    'original_price': 9833,
#    'sale_price': None,
#    'sold_quantity': 500,
#    'available_quantity': 500,
#    'official_store_id': 1859,
#    'official_store_name': 'Farmacias Selma',
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'tags': ['good_quality_thumbnail',
#     'good_quality_picture',
#     'supermarket_eligible',
#     'standard_price_by_channel',
#     'immediate_payment',
#     'cart_eligible',
#     'best_seller_candidate',
#     'shipping_guaranteed'],
#    'shipping': {'store_pick_up': False,
#     'free_shipping': False,
#     'logistic_type': 'fulfillment',
#     'mode': 'me2',
#     'tags': ['fulfillment', 'self_service_out'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2042-07-31T04:00:00.000Z',
#    'seller': {'id': 377840555,
#     'nickname': 'FARMACIA SELMA',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     '_': False,
#     'registration_date': '2018-11-14T13:58:49.000-04:00',
#     'tags': ['brand',
#      'large_seller',
#      'eshop',
#      'mshops',
#      'credits_profile',
#      'messages_as_seller'],
#     'car_dealer_logo': '',
#     'permalink': 'http://perfil.mercadolibre.com.ar/FARMACIA+SELMA',
#     'seller_reputation': {'level_id': '5_green',
#      'power_seller_status': 'platinum',
#      'transactions': {'canceled': 22715,
#       'completed': 578191,
#       'period': 'historic',
#       'ratings': {'negative': 0.06, 'neutral': 0.02, 'positive': 0.92},
#       'total': 600906},
#      'metrics': {'sales': {'period': '60 days', 'completed': 132156},
#       'claims': {'period': '60 days', 'rate': 0.0026, 'value': 364},
#       'delayed_handling_time': {'period': '60 days',
#        'rate': 0.0015,
#        'value': 205},
#       'cancellations': {'period': '60 days', 'rate': 0.002, 'value': 286}}},
#     'eshop': {'eshop_id': 335554,
#      'seller': 377840555,
#      'nick_name': 'FARMACIA SELMA',
#      'eshop_status_id': 1,
#      'site_id': 'MLA',
#      'eshop_experience': 0,
#      'eshop_rubro': None,
#      'eshop_locations': [],
#      'eshop_logo_url': 'http://http2.mlstatic.com/eshops-logo/377840555ve918d7.png'}},
#    'seller_address': {'comment': '',
#     'address_line': '',
#     'id': None,
#     'latitude': None,
#     'longitude': None,
#     'country': {'id': 'AR', 'name': 'Argentina'},
#     'state': {'id': 'AR-B', 'name': 'Buenos Aires'},
#     'city': {'id': None, 'name': 'Olivos'}},
#    'address': {'state_id': 'AR-B',
#     'state_name': 'Buenos Aires',
#     'city_id': None,
#     'city_name': 'Olivos'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '968610',
#      'value_name': 'Dermaglós',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '968610',
#        'name': 'Dermaglós',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 2860837171021627}],
#      'source': 2860837171021627,
#      'value_type': 'list'},
#     {'id': 'LINE',
#      'name': 'Línea',
#      'value_id': '2124246',
#      'value_name': 'Solar',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2124246',
#        'name': 'Solar',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': None,
#      'value_name': 'Efecto Seco',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': 'Efecto Seco',
#        'struct': None,
#        'source': 2860837171021627}],
#      'source': 2860837171021627,
#      'value_type': 'string'},
#     {'id': 'NET_VOLUME',
#      'name': 'Volumen neto',
#      'value_id': None,
#      'value_name': '50 mL',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 50, 'unit': 'mL'},
#      'values': [{'id': None,
#        'name': '50 mL',
#        'struct': {'number': 50, 'unit': 'mL'},
#        'source': 2860837171021627}],
#      'source': 2860837171021627,
#      'value_type': 'number_unit'},
#     {'id': 'NET_WEIGHT',
#      'name': 'Peso neto',
#      'value_id': '135520',
#      'value_name': '50 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 50, 'unit': 'g'},
#      'values': [{'id': '135520',
#        'name': '50 g',
#        'struct': {'unit': 'g', 'number': 50},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_LENGTH',
#      'name': 'Largo del paquete',
#      'value_id': None,
#      'value_name': '14 cm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 14, 'unit': 'cm'},
#      'values': [{'id': None,
#        'name': '14 cm',
#        'struct': {'number': 14, 'unit': 'cm'},
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_WEIGHT',
#      'name': 'Peso del paquete',
#      'value_id': None,
#      'value_name': '100 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 100, 'unit': 'g'},
#      'values': [{'id': None,
#        'name': '100 g',
#        'struct': {'number': 100, 'unit': 'g'},
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'number_unit'},
#     {'id': 'SALE_FORMAT',
#      'name': 'Formato de venta',
#      'value_id': '1359391',
#      'value_name': 'Unidad',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '1359391',
#        'name': 'Unidad',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'UNITS_PER_PACK',
#      'name': 'Unidades por pack',
#      'value_id': '2726554',
#      'value_name': '1',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2726554', 'name': '1', 'struct': None, 'source': 1}],
#      'source': 1,
#      'value_type': 'number'}],
#    'installments': {'quantity': 12,
#     'amount': 1663.05,
#     'rate': 125.6,
#     'currency_id': 'ARS'},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': 'XRMV02275'},
#   {'id': 'MLA1378797977',
#    'title': 'Protector Solar Facial Eucerin Sun Fps 50+ Tono Medio 50ml',
#    'condition': 'new',
#    'thumbnail_id': '855710-MLM48421918388_122021',
#    'catalog_product_id': 'MLA19504960',
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://www.mercadolibre.com.ar/protector-solar-facial-eucerin-sun-fps-50-tono-medio-50ml/p/MLA19504960',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA392400',
#    'domain_id': 'MLA-SUNSCREENS',
#    'thumbnail': 'http://http2.mlstatic.com/D_855710-MLM48421918388_122021-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 3,
#    'price': 11542,
#    'original_price': 15864,
#    'sale_price': None,
#    'sold_quantity': 500,
#    'available_quantity': 250,
#    'official_store_id': 1859,
#    'official_store_name': 'Farmacias Selma',
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'tags': ['supermarket_eligible',
#     'good_quality_thumbnail',
#     'standard_price_by_channel',
#     'deal_of_the_day',
#     'immediate_payment',
#     'cart_eligible',
#     'best_seller_candidate',
#     'shipping_guaranteed'],
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'fulfillment',
#     'mode': 'me2',
#     'tags': ['fulfillment',
#      'MLA-CH-THRESHOLD-AGO-2023',
#      'self_service_out',
#      'mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2043-07-16T04:00:00.000Z',
#    'seller': {'id': 377840555,
#     'nickname': 'FARMACIA SELMA',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     '_': False,
#     'registration_date': '2018-11-14T13:58:49.000-04:00',
#     'tags': ['brand',
#      'large_seller',
#      'eshop',
#      'mshops',
#      'credits_profile',
#      'messages_as_seller'],
#     'car_dealer_logo': '',
#     'permalink': 'http://perfil.mercadolibre.com.ar/FARMACIA+SELMA',
#     'seller_reputation': {'level_id': '5_green',
#      'power_seller_status': 'platinum',
#      'transactions': {'canceled': 22715,
#       'completed': 578191,
#       'period': 'historic',
#       'ratings': {'negative': 0.06, 'neutral': 0.02, 'positive': 0.92},
#       'total': 600906},
#      'metrics': {'sales': {'period': '60 days', 'completed': 132156},
#       'claims': {'period': '60 days', 'rate': 0.0026, 'value': 364},
#       'delayed_handling_time': {'period': '60 days',
#        'rate': 0.0015,
#        'value': 205},
#       'cancellations': {'period': '60 days', 'rate': 0.002, 'value': 286}}},
#     'eshop': {'eshop_id': 335554,
#      'seller': 377840555,
#      'nick_name': 'FARMACIA SELMA',
#      'eshop_status_id': 1,
#      'site_id': 'MLA',
#      'eshop_experience': 0,
#      'eshop_rubro': None,
#      'eshop_locations': [],
#      'eshop_logo_url': 'http://http2.mlstatic.com/eshops-logo/377840555ve918d7.png'}},
#    'seller_address': {'comment': '',
#     'address_line': '',
#     'id': None,
#     'latitude': None,
#     'longitude': None,
#     'country': {'id': 'AR', 'name': 'Argentina'},
#     'state': {'id': 'AR-B', 'name': 'Buenos Aires'},
#     'city': {'id': None, 'name': 'Olivos'}},
#    'address': {'state_id': 'AR-B',
#     'state_name': 'Buenos Aires',
#     'city_id': None,
#     'city_name': 'Olivos'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '902988',
#      'value_name': 'Eucerin',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '902988',
#        'name': 'Eucerin',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 2860837171021627}],
#      'source': 2860837171021627,
#      'value_type': 'list'},
#     {'id': 'LINE',
#      'name': 'Línea',
#      'value_id': '8694441',
#      'value_name': 'Oil Control',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '8694441',
#        'name': 'Oil Control',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '8694462',
#      'value_name': 'Toque Seco',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '8694462',
#        'name': 'Toque Seco',
#        'struct': None,
#        'source': 3942444344910321}],
#      'source': 3942444344910321,
#      'value_type': 'string'},
#     {'id': 'NET_VOLUME',
#      'name': 'Volumen neto',
#      'value_id': '112837',
#      'value_name': '50 mL',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 50, 'unit': 'mL'},
#      'values': [{'id': '112837',
#        'name': '50 mL',
#        'struct': {'unit': 'mL', 'number': 50},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'},
#     {'id': 'NET_WEIGHT',
#      'name': 'Peso neto',
#      'value_id': None,
#      'value_name': '50 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 50, 'unit': 'g'},
#      'values': [{'id': None,
#        'name': '50 g',
#        'struct': {'unit': 'g', 'number': 50},
#        'source': 2860837171021627}],
#      'source': 2860837171021627,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_LENGTH',
#      'name': 'Largo del paquete',
#      'value_id': None,
#      'value_name': '4.4 cm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 4.4, 'unit': 'cm'},
#      'values': [{'id': None,
#        'name': '4.4 cm',
#        'struct': {'number': 4.4, 'unit': 'cm'},
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_WEIGHT',
#      'name': 'Peso del paquete',
#      'value_id': None,
#      'value_name': '100 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 100, 'unit': 'g'},
#      'values': [{'id': None,
#        'name': '100 g',
#        'struct': {'number': 100, 'unit': 'g'},
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'number_unit'},
#     {'id': 'SALE_FORMAT',
#      'name': 'Formato de venta',
#      'value_id': '1359391',
#      'value_name': 'Unidad',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '1359391',
#        'name': 'Unidad',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'UNITS_PER_PACK',
#      'name': 'Unidades por pack',
#      'value_id': '2726554',
#      'value_name': '1',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2726554', 'name': '1', 'struct': None, 'source': 1}],
#      'source': 1,
#      'value_type': 'number'}],
#    'installments': {'quantity': 12,
#     'amount': 2169.9,
#     'rate': 125.6,
#     'currency_id': 'ARS'},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': 'PQCQ06721'},
#   {'id': 'MLA1181877593',
#    'title': 'Anthelios Uvmune 400 Fluido Invisible50+ La Roche-posay 50ml',
#    'condition': 'new',
#    'thumbnail_id': '966734-MLA51230469218_082022',
#    'catalog_product_id': 'MLA19638909',
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://www.mercadolibre.com.ar/anthelios-uvmune-400-fluido-invisible50-la-roche-posay-50ml/p/MLA19638909',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA392400',
#    'domain_id': 'MLA-SUNSCREENS',
#    'thumbnail': 'http://http2.mlstatic.com/D_966734-MLA51230469218_082022-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 4,
#    'price': 12232,
#    'original_price': 16310,
#    'sale_price': None,
#    'sold_quantity': 500,
#    'available_quantity': 500,
#    'official_store_id': 1859,
#    'official_store_name': 'Farmacias Selma',
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'tags': ['good_quality_picture',
#     'standard_price_by_channel',
#     'good_quality_thumbnail',
#     'immediate_payment',
#     'cart_eligible',
#     'best_seller_candidate',
#     'shipping_guaranteed'],
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'cross_docking',
#     'mode': 'me2',
#     'tags': ['MLA-chg-threshold-Feb-23',
#      'self_service_in',
#      'mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2043-04-28T14:04:01.000Z',
#    'seller': {'id': 377840555,
#     'nickname': 'FARMACIA SELMA',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     '_': False,
#     'registration_date': '2018-11-14T13:58:49.000-04:00',
#     'tags': ['brand',
#      'large_seller',
#      'eshop',
#      'mshops',
#      'credits_profile',
#      'messages_as_seller'],
#     'car_dealer_logo': '',
#     'permalink': 'http://perfil.mercadolibre.com.ar/FARMACIA+SELMA',
#     'seller_reputation': {'level_id': '5_green',
#      'power_seller_status': 'platinum',
#      'transactions': {'canceled': 22715,
#       'completed': 578191,
#       'period': 'historic',
#       'ratings': {'negative': 0.06, 'neutral': 0.02, 'positive': 0.92},
#       'total': 600906},
#      'metrics': {'sales': {'period': '60 days', 'completed': 132156},
#       'claims': {'period': '60 days', 'rate': 0.0026, 'value': 364},
#       'delayed_handling_time': {'period': '60 days',
#        'rate': 0.0015,
#        'value': 205},
#       'cancellations': {'period': '60 days', 'rate': 0.002, 'value': 286}}},
#     'eshop': {'eshop_id': 335554,
#      'seller': 377840555,
#      'nick_name': 'FARMACIA SELMA',
#      'eshop_status_id': 1,
#      'site_id': 'MLA',
#      'eshop_experience': 0,
#      'eshop_rubro': None,
#      'eshop_locations': [],
#      'eshop_logo_url': 'http://http2.mlstatic.com/eshops-logo/377840555ve918d7.png'}},
#    'seller_address': {'comment': '',
#     'address_line': '',
#     'id': None,
#     'latitude': None,
#     'longitude': None,
#     'country': {'id': 'AR', 'name': 'Argentina'},
#     'state': {'id': 'AR-B', 'name': 'Buenos Aires'},
#     'city': {'id': None, 'name': 'Olivos'}},
#    'address': {'state_id': 'AR-B',
#     'state_name': 'Buenos Aires',
#     'city_id': None,
#     'city_name': 'Olivos'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '1515703',
#      'value_name': 'La Roche-Posay',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '1515703',
#        'name': 'La Roche-Posay',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'LINE',
#      'name': 'Línea',
#      'value_id': '8694443',
#      'value_name': 'Anthelios',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '8694443',
#        'name': 'Anthelios',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': None,
#      'value_name': 'Anthelios Uv Mune Fluido Invisible',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': 'Anthelios Uv Mune Fluido Invisible',
#        'struct': None,
#        'source': 3376461333454861}],
#      'source': 3376461333454861,
#      'value_type': 'string'},
#     {'id': 'NET_VOLUME',
#      'name': 'Volumen neto',
#      'value_id': '112837',
#      'value_name': '50 mL',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 50, 'unit': 'mL'},
#      'values': [{'id': '112837',
#        'name': '50 mL',
#        'struct': {'number': 50, 'unit': 'mL'},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'},
#     {'id': 'SALE_FORMAT',
#      'name': 'Formato de venta',
#      'value_id': '1359391',
#      'value_name': 'Unidad',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '1359391',
#        'name': 'Unidad',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'UNITS_PER_PACK',
#      'name': 'Unidades por pack',
#      'value_id': '2726554',
#      'value_name': '1',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2726554', 'name': '1', 'struct': None, 'source': 1}],
#      'source': 1,
#      'value_type': 'number'}],
#    'installments': {'quantity': 12,
#     'amount': 2299.62,
#     'rate': 125.6,
#     'currency_id': 'ARS'},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': None},
#   {'id': 'MLA1153275613',
#    'title': 'Isdin Fotoprotector Spf50+ Fusion Water Toque Seco X 50 Ml',
#    'condition': 'new',
#    'thumbnail_id': '790529-MLA53244254168_012023',
#    'catalog_product_id': 'MLA19509077',
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://www.mercadolibre.com.ar/isdin-fotoprotector-spf50-fusion-water-toque-seco-x-50-ml/p/MLA19509077',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA392400',
#    'domain_id': 'MLA-SUNSCREENS',
#    'thumbnail': 'http://http2.mlstatic.com/D_790529-MLA53244254168_012023-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 6,
#    'price': 15549.22,
#    'original_price': None,
#    'sale_price': None,
#    'sold_quantity': 500,
#    'available_quantity': 100,
#    'official_store_id': None,
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'tags': ['good_quality_picture',
#     'brand_verified',
#     'good_quality_thumbnail',
#     'immediate_payment',
#     'cart_eligible',
#     'best_seller_candidate'],
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'cross_docking',
#     'mode': 'me2',
#     'tags': ['self_service_in', 'fbm_in_process', 'mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2042-08-11T04:00:00.000Z',
#    'seller': {'id': 506786485,
#     'nickname': 'FARMACIA GENERALPAZ',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     '_': False,
#     'registration_date': '2019-12-26T10:37:45.000-04:00',
#     'tags': ['normal', 'credits_profile', 'mshops', 'messages_as_seller'],
#     'car_dealer_logo': '',
#     'permalink': 'http://perfil.mercadolibre.com.ar/FARMACIA+GENERALPAZ',
#     'seller_reputation': {'level_id': '5_green',
#      'power_seller_status': 'platinum',
#      'transactions': {'canceled': 2350,
#       'completed': 44582,
#       'period': 'historic',
#       'ratings': {'negative': 0.15, 'neutral': 0.02, 'positive': 0.83},
#       'total': 46932},
#      'metrics': {'sales': {'period': '60 days', 'completed': 8146},
#       'claims': {'period': '60 days', 'rate': 0.003, 'value': 26},
#       'delayed_handling_time': {'period': '60 days',
#        'rate': 0.0125,
#        'value': 103},
#       'cancellations': {'period': '60 days', 'rate': 0.0027, 'value': 23}}}},
#    'seller_address': {'comment': '',
#     'address_line': '',
#     'id': None,
#     'latitude': None,
#     'longitude': None,
#     'country': {'id': 'AR', 'name': 'Argentina'},
#     'state': {'id': 'AR-X', 'name': 'Córdoba'},
#     'city': {'id': 'TUxBQ0NBUGNiZGQx', 'name': 'Córdoba'}},
#    'address': {'state_id': 'AR-X',
#     'state_name': 'Córdoba',
#     'city_id': 'TUxBQ0NBUGNiZGQx',
#     'city_name': 'Córdoba'},
#    'attributes': [{'id': 'TOTAL_CONTENT_VOLUME',
#      'name': 'Contenido total en volumen',
#      'value_id': None,
#      'value_name': '50 mL',
#      'attribute_group_id': '',
#      'attribute_group_name': '',
#      'value_struct': {'number': 50, 'unit': 'mL'},
#      'values': [{'id': None,
#        'name': '50 mL',
#        'struct': {'unit': 'mL', 'number': 50},
#        'source': 8492822877720875}],
#      'source': 8492822877720875,
#      'value_type': 'number_unit'},
#     {'id': 'UNITS_PER_PACKAGE',
#      'name': 'Unidades por envase',
#      'value_id': None,
#      'value_name': '1',
#      'attribute_group_id': '',
#      'attribute_group_name': '',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': '1',
#        'struct': None,
#        'source': 3376461333454861}],
#      'source': 3376461333454861,
#      'value_type': 'integer'},
#     {'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '1134713',
#      'value_name': 'Isdin',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '1134713',
#        'name': 'Isdin',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 4954751883138633}],
#      'source': 4954751883138633,
#      'value_type': 'list'},
#     {'id': 'LINE',
#      'name': 'Línea',
#      'value_id': '3416010',
#      'value_name': 'Fotoprotector',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '3416010',
#        'name': 'Fotoprotector',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '8712197',
#      'value_name': 'Fusion Water',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '8712197',
#        'name': 'Fusion Water',
#        'struct': None,
#        'source': 1000427007642219}],
#      'source': 1000427007642219,
#      'value_type': 'string'},
#     {'id': 'NET_VOLUME',
#      'name': 'Volumen neto',
#      'value_id': '112837',
#      'value_name': '50 mL',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 50, 'unit': 'mL'},
#      'values': [{'id': '112837',
#        'name': '50 mL',
#        'struct': {'number': 50, 'unit': 'mL'},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'},
#     {'id': 'NET_WEIGHT',
#      'name': 'Peso neto',
#      'value_id': None,
#      'value_name': '50 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 50, 'unit': 'g'},
#      'values': [{'id': None,
#        'name': '50 g',
#        'struct': {'number': 50, 'unit': 'g'},
#        'source': 3376461333454861}],
#      'source': 3376461333454861,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_LENGTH',
#      'name': 'Largo del paquete',
#      'value_id': None,
#      'value_name': '13.8 cm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 13.8, 'unit': 'cm'},
#      'values': [{'id': None,
#        'name': '13.8 cm',
#        'struct': {'number': 13.8, 'unit': 'cm'},
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_WEIGHT',
#      'name': 'Peso del paquete',
#      'value_id': None,
#      'value_name': '80 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 80, 'unit': 'g'},
#      'values': [{'id': None,
#        'name': '80 g',
#        'struct': {'number': 80, 'unit': 'g'},
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'number_unit'},
#     {'id': 'SALE_FORMAT',
#      'name': 'Formato de venta',
#      'value_id': '1359391',
#      'value_name': 'Unidad',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '1359391',
#        'name': 'Unidad',
#        'struct': None,
#        'source': 3376461333454861}],
#      'source': 3376461333454861,
#      'value_type': 'list'},
#     {'id': 'UNITS_PER_PACK',
#      'name': 'Unidades por pack',
#      'value_id': None,
#      'value_name': '1',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': '1',
#        'struct': None,
#        'source': 3376461333454861}],
#      'source': 3376461333454861,
#      'value_type': 'number'}],
#    'installments': {'quantity': 12,
#     'amount': 2923.25,
#     'rate': 125.6,
#     'currency_id': 'ARS'},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': 'HQPT44242'},
#   {'id': 'MLA1364862419',
#    'title': 'Fotoprotector Isdin Fusion Water Color Ligth  Spf 50 X 50ml',
#    'condition': 'new',
#    'thumbnail_id': '719870-MLA52163222583_102022',
#    'catalog_product_id': 'MLA20067103',
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://www.mercadolibre.com.ar/fotoprotector-isdin-fusion-water-color-ligth-spf-50-x-50ml/p/MLA20067103',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA392400',
#    'domain_id': 'MLA-SUNSCREENS',
#    'thumbnail': 'http://http2.mlstatic.com/D_719870-MLA52163222583_102022-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 7,
#    'price': 16538.96,
#    'original_price': None,
#    'sale_price': None,
#    'sold_quantity': 200,
#    'available_quantity': 1,
#    'official_store_id': None,
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'tags': ['moderation_penalty',
#     'immediate_payment',
#     'cart_eligible',
#     'shipping_guaranteed'],
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'cross_docking',
#     'mode': 'me2',
#     'tags': ['self_service_in', 'mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2043-03-31T04:00:00.000Z',
#    'seller': {'id': 313043158,
#     'nickname': 'FARMABELÉN',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     '_': False,
#     'registration_date': '2018-04-06T19:11:23.000-04:00',
#     'tags': ['normal',
#      'eshop',
#      'mshops',
#      'credits_profile',
#      'messages_as_seller'],
#     'car_dealer_logo': '',
#     'permalink': 'http://perfil.mercadolibre.com.ar/FARMABELEN.',
#     'seller_reputation': {'level_id': '5_green',
#      'power_seller_status': 'platinum',
#      'transactions': {'canceled': 6097,
#       'completed': 135984,
#       'period': 'historic',
#       'ratings': {'negative': 0.04, 'neutral': 0.02, 'positive': 0.94},
#       'total': 142081},
#      'metrics': {'sales': {'period': '60 days', 'completed': 32297},
#       'claims': {'period': '60 days', 'rate': 0.0032, 'value': 107},
#       'delayed_handling_time': {'period': '60 days',
#        'rate': 0.0082,
#        'value': 265},
#       'cancellations': {'period': '60 days', 'rate': 0.0016, 'value': 54}}},
#     'eshop': {'eshop_id': 424614,
#      'seller': 313043158,
#      'nick_name': 'FARMABELÉN',
#      'eshop_status_id': 1,
#      'site_id': 'MLA',
#      'eshop_experience': 0,
#      'eshop_rubro': None,
#      'eshop_locations': [],
#      'eshop_logo_url': 'http://http2.mlstatic.com/eshops-logo/313043158vfe8a79.png'}},
#    'seller_address': {'comment': '',
#     'address_line': '',
#     'id': None,
#     'latitude': None,
#     'longitude': None,
#     'country': {'id': 'AR', 'name': 'Argentina'},
#     'state': {'id': 'AR-C', 'name': 'Capital Federal'},
#     'city': {'id': 'TUxBQlZJTDQ4MzBa', 'name': 'Villa Lugano'}},
#    'address': {'state_id': 'AR-C',
#     'state_name': 'Capital Federal',
#     'city_id': 'TUxBQlZJTDQ4MzBa',
#     'city_name': 'Villa Lugano'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '1134713',
#      'value_name': 'Isdin',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '1134713',
#        'name': 'Isdin',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 6808261514773724}],
#      'source': 6808261514773724,
#      'value_type': 'list'},
#     {'id': 'LINE',
#      'name': 'Línea',
#      'value_id': '13388244',
#      'value_name': 'Fusion Water',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '13388244',
#        'name': 'Fusion Water',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '14006945',
#      'value_name': 'Color Ligth',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '14006945',
#        'name': 'Color Ligth',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'NET_VOLUME',
#      'name': 'Volumen neto',
#      'value_id': '112837',
#      'value_name': '50 mL',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 50, 'unit': 'mL'},
#      'values': [{'id': '112837',
#        'name': '50 mL',
#        'struct': {'number': 50, 'unit': 'mL'},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'},
#     {'id': 'NET_WEIGHT',
#      'name': 'Peso neto',
#      'value_id': '135520',
#      'value_name': '50 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 50, 'unit': 'g'},
#      'values': [{'id': '135520',
#        'name': '50 g',
#        'struct': {'number': 50, 'unit': 'g'},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'},
#     {'id': 'SALE_FORMAT',
#      'name': 'Formato de venta',
#      'value_id': '1359391',
#      'value_name': 'Unidad',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '1359391',
#        'name': 'Unidad',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'UNITS_PER_PACK',
#      'name': 'Unidades por pack',
#      'value_id': '2726554',
#      'value_name': '1',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2726554', 'name': '1', 'struct': None, 'source': 1}],
#      'source': 1,
#      'value_type': 'number'}],
#    'installments': {'quantity': 12,
#     'amount': 3109.32,
#     'rate': 125.6,
#     'currency_id': 'ARS'},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': 'SLFY22351'},
#   {'id': 'MLA1387160703',
#    'title': 'Protector Solar Dermaglós Fps 40 Fps 40 Efecto Seco En Crema De 180 G',
#    'condition': 'new',
#    'thumbnail_id': '837601-MLA44740497066_012021',
#    'catalog_product_id': 'MLA16048346',
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://www.mercadolibre.com.ar/protector-solar-dermaglos-fps-40-fps-40-efecto-seco-en-crema-de-180-g/p/MLA16048346',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA392400',
#    'domain_id': 'MLA-SUNSCREENS',
#    'thumbnail': 'http://http2.mlstatic.com/D_837601-MLA44740497066_012021-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 8,
#    'price': 9190,
#    'original_price': None,
#    'sale_price': None,
#    'sold_quantity': 25,
#    'available_quantity': 1,
#    'official_store_id': None,
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'tags': ['good_quality_thumbnail',
#     'immediate_payment',
#     'cart_eligible',
#     'best_seller_candidate'],
#    'shipping': {'store_pick_up': False,
#     'free_shipping': False,
#     'logistic_type': 'xd_drop_off',
#     'mode': 'me2',
#     'tags': [],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2043-09-03T04:00:00.000Z',
#    'seller': {'id': 726655203,
#     'nickname': 'MAGASHOPEXPRES',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     '_': False,
#     'registration_date': '2021-03-10T13:19:24.000-04:00',
#     'tags': ['normal', 'credits_profile', 'mshops', 'messages_as_seller'],
#     'car_dealer_logo': '',
#     'permalink': 'http://perfil.mercadolibre.com.ar/MAGASHOPEXPRES',
#     'seller_reputation': {'level_id': '5_green',
#      'power_seller_status': 'platinum',
#      'transactions': {'canceled': 104,
#       'completed': 3401,
#       'period': 'historic',
#       'ratings': {'negative': 0.06, 'neutral': 0, 'positive': 0.94},
#       'total': 3505},
#      'metrics': {'sales': {'period': '60 days', 'completed': 2665},
#       'claims': {'period': '60 days', 'rate': 0.0007, 'value': 2},
#       'delayed_handling_time': {'period': '60 days',
#        'rate': 0.022,
#        'value': 53},
#       'cancellations': {'period': '60 days', 'rate': 0, 'value': 0}}}},
#    'seller_address': {'comment': '',
#     'address_line': '',
#     'id': None,
#     'latitude': None,
#     'longitude': None,
#     'country': {'id': 'AR', 'name': 'Argentina'},
#     'state': {'id': 'AR-B', 'name': 'Buenos Aires'},
#     'city': {'id': 'TUxBQ1FVSWI1MzY', 'name': 'Quilmes'}},
#    'address': {'state_id': 'AR-B',
#     'state_name': 'Buenos Aires',
#     'city_id': 'TUxBQ1FVSWI1MzY',
#     'city_name': 'Quilmes'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '968610',
#      'value_name': 'Dermaglós',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '968610',
#        'name': 'Dermaglós',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 6808261514773724}],
#      'source': 6808261514773724,
#      'value_type': 'list'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '8868322',
#      'value_name': 'FPS 40 Efecto Seco',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '8868322',
#        'name': 'FPS 40 Efecto Seco',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'NET_WEIGHT',
#      'name': 'Peso neto',
#      'value_id': '139202',
#      'value_name': '180 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 180, 'unit': 'g'},
#      'values': [{'id': '139202',
#        'name': '180 g',
#        'struct': {'unit': 'g', 'number': 180},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'}],
#    'installments': {'quantity': 12,
#     'amount': 1727.72,
#     'rate': 125.6,
#     'currency_id': 'ARS'},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': 'YSIG82018'},
#   {'id': 'MLA923745889',
#    'title': 'Protector Solar Color Efecto Mate Anthelios Fps 50+ La Roche',
#    'condition': 'new',
#    'thumbnail_id': '673481-MLA53565286212_022023',
#    'catalog_product_id': 'MLA16048424',
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://www.mercadolibre.com.ar/protector-solar-color-efecto-mate-anthelios-fps-50-la-roche/p/MLA16048424',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA392400',
#    'domain_id': 'MLA-SUNSCREENS',
#    'thumbnail': 'http://http2.mlstatic.com/D_673481-MLA53565286212_022023-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 9,
#    'price': 11017,
#    'original_price': 14690,
#    'sale_price': None,
#    'sold_quantity': 500,
#    'available_quantity': 250,
#    'official_store_id': 1859,
#    'official_store_name': 'Farmacias Selma',
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'tags': ['moderation_penalty',
#     'good_quality_picture',
#     'loyalty_discount_eligible',
#     'good_quality_thumbnail',
#     'standard_price_by_channel',
#     'immediate_payment',
#     'cart_eligible',
#     'best_seller_candidate',
#     'shipping_guaranteed'],
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'cross_docking',
#     'mode': 'me2',
#     'tags': ['self_service_in', 'mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2041-06-09T16:22:07.000Z',
#    'seller': {'id': 377840555,
#     'nickname': 'FARMACIA SELMA',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     '_': False,
#     'registration_date': '2018-11-14T13:58:49.000-04:00',
#     'tags': ['brand',
#      'large_seller',
#      'eshop',
#      'mshops',
#      'credits_profile',
#      'messages_as_seller'],
#     'car_dealer_logo': '',
#     'permalink': 'http://perfil.mercadolibre.com.ar/FARMACIA+SELMA',
# ...
#     {'id': '12935365', 'name': 'Deskin', 'results': 5},
#     {'id': '12902173', 'name': 'Sentida Botánica', 'results': 5},
#     {'id': '1215650', 'name': 'Mira Dror', 'results': 5},
#     {'id': '1134697', 'name': 'Bioderma', 'results': 5},
#     {'id': '24179', 'name': 'Yanbal', 'results': 4},
#     {'id': '182722', 'name': 'Ozone', 'results': 4},
#     {'id': '13912112', 'name': 'Cassara', 'results': 4},
#     {'id': '13912108', 'name': 'Fotosol', 'results': 4},
#     {'id': '13798346', 'name': 'Brown Bee', 'results': 4},
#     {'id': '13389404', 'name': 'Umbrella Intelligent', 'results': 4},
#     {'id': '1220699', 'name': "L'Oréal Paris", 'results': 4},
#     {'id': '8694794', 'name': 'Algabo', 'results': 3},
#     {'id': '6994122', 'name': "A'pieu", 'results': 3},
#     {'id': '6538925', 'name': 'Fortbenton', 'results': 3},
#     {'id': '5752495', 'name': 'Lure', 'results': 3},
#     {'id': '428935', 'name': 'Neutrogena', 'results': 3},
#     {'id': '3453779', 'name': 'The Ordinary', 'results': 3},
#     {'id': '2766664', 'name': 'Arvensis', 'results': 3},
#     {'id': '23130', 'name': 'O Boticário', 'results': 3},
#     {'id': '13914813', 'name': 'Emynent', 'results': 3},
#     {'id': '12964724', 'name': 'La Roche Posay', 'results': 3},
#     {'id': '968593', 'name': "Fiorel'a", 'results': 2},
#     {'id': '7236006', 'name': 'Triumph & Disaster', 'results': 2},
#     {'id': '6875099', 'name': 'Dermaprof', 'results': 2},
#     {'id': '6110178', 'name': 'Coolibar', 'results': 2},
#     {'id': '428925', 'name': 'Cicatricure', 'results': 2},
#     {'id': '3764968', 'name': 'Las Margaritas', 'results': 2},
#     {'id': '2899746', 'name': 'Poseidon', 'results': 2},
#     {'id': '2671247', 'name': 'Bagués', 'results': 2},
#     {'id': '2645264', 'name': 'Selecta', 'results': 2},
#     {'id': '2642690', 'name': 'Arex', 'results': 2},
#     {'id': '2531683', 'name': 'GH', 'results': 2},
#     {'id': '24052', 'name': 'Biotherm', 'results': 2},
#     {'id': '2305581', 'name': 'Fórmula Dra. Norma Bustos', 'results': 2},
#     {'id': '21708150', 'name': 'CVS', 'results': 2},
#     {'id': '15119343', 'name': 'Novaderma', 'results': 2},
#     {'id': '13804823', 'name': 'Avene Eau Thermale', 'results': 2},
#     {'id': '13429130', 'name': 'Sun Bum', 'results': 2},
#     {'id': '13407931', 'name': 'Umbrella', 'results': 2},
#     {'id': '13393994', 'name': 'Elta Md', 'results': 2},
#     {'id': '13389409', 'name': 'Midermus', 'results': 2},
#     {'id': '12931769', 'name': 'Andrómaco', 'results': 2},
#     {'id': '11874145', 'name': 'Nivea Sun', 'results': 2},
#     {'id': '1162050', 'name': 'Missha', 'results': 2},
#     {'id': '11042411', 'name': 'Heliocare', 'results': 2},
#     {'id': '968590', 'name': 'Zine', 'results': 1},
#     {'id': '9543388', 'name': 'Natureza', 'results': 1},
#     {'id': '898841', 'name': 'Venum', 'results': 1},
#     {'id': '6697470', 'name': 'Goodsense', 'results': 1},
#     {'id': '5006312', 'name': 'Natufarma', 'results': 1},
#     {'id': '4965190', 'name': 'Pharmatrix', 'results': 1},
#     {'id': '3917351', 'name': 'Ringside', 'results': 1},
#     {'id': '3813571', 'name': 'H&G', 'results': 1},
#     {'id': '3759492', 'name': 'Bioré', 'results': 1},
#     {'id': '3334896', 'name': 'Tierras del Volcán', 'results': 1},
#     {'id': '2955496', 'name': 'Banana Boat', 'results': 1},
#     {'id': '2897433', 'name': 'La Mer', 'results': 1},
#     {'id': '2720789', 'name': 'CeraVe', 'results': 1},
#     {'id': '2707209', 'name': 'Murad', 'results': 1},
#     {'id': '2642729', 'name': 'Innisfree', 'results': 1},
#     {'id': '250226', 'name': 'Amodil', 'results': 1},
#     {'id': '2500208', 'name': 'Laura Mercier', 'results': 1},
#     {'id': '249084', 'name': 'Monique Arnold', 'results': 1},
#     {'id': '23748', 'name': 'Millanel', 'results': 1},
#     {'id': '23662', 'name': 'Estée Lauder', 'results': 1},
#     {'id': '23255', 'name': 'Guerlain', 'results': 1},
#     {'id': '2310276', 'name': 'Forever Living', 'results': 1},
#     {'id': '23057', 'name': 'Givenchy', 'results': 1},
#     {'id': '23042', 'name': 'Lancôme', 'results': 1},
#     {'id': '22982', 'name': 'Sisley', 'results': 1},
#     {'id': '22453568', 'name': 'LuvréPro', 'results': 1},
#     {'id': '2136629', 'name': 'Seytú', 'results': 1},
#     {'id': '19163495', 'name': 'Oficinalis', 'results': 1},
#     {'id': '17612231', 'name': 'Skin1004', 'results': 1},
#     {'id': '16490574', 'name': 'Drmtlgy', 'results': 1},
#     {'id': '13765820', 'name': 'Neogen', 'results': 1},
#     {'id': '13759627', 'name': 'Vansame', 'results': 1},
#     {'id': '13629817', 'name': 'Anthelios', 'results': 1},
#     {'id': '13074490', 'name': 'Crembel', 'results': 1},
#     {'id': '12947887', 'name': 'Cosrx', 'results': 1},
#     {'id': '12902213', 'name': 'Vida Natural', 'results': 1},
#     {'id': '12901792', 'name': 'Milaborit', 'results': 1},
#     {'id': '1262696', 'name': 'Biocom', 'results': 1},
#     {'id': '12472438', 'name': 'LRP', 'results': 1},
#     {'id': '12355446', 'name': 'Openfarma', 'results': 1},
#     {'id': '12355403', 'name': 'Dr. Duval', 'results': 1},
#     {'id': '12355391', 'name': 'Collage', 'results': 1}]},
#   {'id': 'IS_CRUELTY_FREE',
#    'name': 'Otras características',
#    'type': 'boolean',
#    'values': [{'id': '242085',
#      'name': 'Es libre de crueldad',
#      'results': 1157}]},
#   {'id': 'IS_GLUTEN_FREE',
#    'name': 'Otras características',
#    'type': 'boolean',
#    'values': [{'id': '242085', 'name': 'Es libre de gluten', 'results': 847}]},
#   {'id': 'IS_HYPOALLERGENIC_PRODUCT',
#    'name': 'Otras características',
#    'type': 'boolean',
#    'values': [{'id': '242085',
#      'name': 'Es un producto hipoalergénico',
#      'results': 2291}]},
#   {'id': 'IS_PARABENS_FREE',
#    'name': 'Otras características',
#    'type': 'boolean',
#    'values': [{'id': '242085',
#      'name': 'Es libre de parabenos',
#      'results': 1421}]},
#   {'id': 'IS_WATER_RESISTANT',
#    'name': 'Otras características',
#    'type': 'boolean',
#    'values': [{'id': '242085',
#      'name': 'Es resistente al agua',
#      'results': 2262}]},
#   {'id': 'ITEM_CONDITION',
#    'name': 'Condición',
#    'type': 'STRING',
#    'values': [{'id': '2230284', 'name': 'Nuevo', 'results': 2897}]},
#   {'id': 'MIN_RECOMMENDED_AGE',
#    'name': 'Edad mínima recomendada',
#    'type': 'range',
#    'values': [{'id': '(*-3años)', 'name': 'Menos de 3 años', 'results': 176},
#     {'id': '[3años-6años)', 'name': '3 a 5 años', 'results': 193},
#     {'id': '[6años-15años)', 'name': '6 a 14 años', 'results': 243},
#     {'id': '[15años-*)', 'name': '15 años o más', 'results': 339}]},
#   {'id': 'NET_WEIGHT',
#    'name': 'Peso neto',
#    'type': 'range',
#    'values': [{'id': '(*-50g]', 'name': '50 g o menos', 'results': 678},
#     {'id': '[50g-52g]', 'name': '50 a 52 g', 'results': 508},
#     {'id': '[52g-150g]', 'name': '52 a 150 g', 'results': 530},
#     {'id': '[150g-*)', 'name': '150 g o más', 'results': 641}]},
#   {'id': 'SALE_FORMAT',
#    'name': 'Formato de venta',
#    'type': 'STRING',
#    'values': [{'id': '1359391', 'name': 'Unidad', 'results': 2312},
#     {'id': '1359392', 'name': 'Pack', 'results': 137}]},
#   {'id': 'SUNSCREEN_FORMAT',
#    'name': 'Formato',
#    'type': 'STRING',
#    'values': [{'id': '7176522', 'name': 'Crema', 'results': 958},
#     {'id': '8920501', 'name': 'Emulsión', 'results': 359},
#     {'id': '7176524', 'name': 'Spray', 'results': 352},
#     {'id': '8694330', 'name': 'Fluído', 'results': 222},
#     {'id': '8694332', 'name': 'Pomo', 'results': 132},
#     {'id': '13233638', 'name': 'Gel crema', 'results': 126},
#     {'id': '8920500', 'name': 'Spray continuo', 'results': 109},
#     {'id': '7176523', 'name': 'Gel', 'results': 38},
#     {'id': '8694324', 'name': 'Bruma', 'results': 36},
#     {'id': '8694331', 'name': 'Loción', 'results': 34},
#     {'id': '8712212', 'name': 'Barra', 'results': 27},
#     {'id': '8694337', 'name': 'Gel-Crema', 'results': 25},
#     {'id': '8694336', 'name': 'Crema-Gel', 'results': 18},
#     {'id': '8694328', 'name': 'Aerosol', 'results': 14},
#     {'id': '8709795', 'name': 'Tubo dosificador', 'results': 8},
#     {'id': '8782201', 'name': 'Aceite', 'results': 7},
#     {'id': '8694334', 'name': 'Shaka-Shaka', 'results': 6},
#     {'id': '8712214', 'name': 'Polvo', 'results': 5},
#     {'id': '8694333', 'name': 'Compacto', 'results': 5},
#     {'id': '8709798', 'name': 'Tubo', 'results': 4},
#     {'id': '9162730', 'name': 'Toque seco', 'results': 3},
#     {'id': '8868334', 'name': 'Lápiz labial', 'results': 2},
#     {'id': '8694329', 'name': 'Sérum', 'results': 2},
#     {'id': '8694326', 'name': 'Stick', 'results': 2},
#     {'id': '8694327', 'name': 'Mousse', 'results': 1},
#     {'id': '8694322', 'name': 'Tic-Tac', 'results': 1}]},
#   {'id': 'UNITS_PER_PACK',
#    'name': 'Unidades por pack',
#    'type': 'range',
#    'values': [{'id': '[1-1]', 'name': 'Por unidad', 'results': 2294},
#     {'id': '[2-3)', 'name': '2 unidades', 'results': 56},
#     {'id': '[3-*)', 'name': '3 unidades o más', 'results': 64}]},
#   {'id': 'product',
#    'name': 'Producto',
#    'type': 'text',
#    'values': [{'id': 'MLA16048240',
#      'name': 'Dermaglós Solar FPS 40 Emulsión',
#      'results': 52},
#     {'id': 'MLA16048268',
#      'name': 'Dermaglós Solar FPS 50 Emulsión',
#      'results': 50},
#     {'id': 'MLA16048248',
#      'name': 'Eucerin Oil Control Toque Seco Gel crema',
#      'results': 49},
#     {'id': 'MLA16048239',
#      'name': 'Protector Solar Dermaglós FPS40 Emulsión x250ml',
#      'results': 43},
#     {'id': 'MLA16048420', 'name': 'Dermaglós FPS 30 Emulsión', 'results': 39},
#     {'id': 'MLA16048269',
#      'name': 'Eucerin Solar Fluid Anti Edad Facial Fps50 X 50 Ml',
#      'results': 35},
#     {'id': 'MLA16048270',
#      'name': 'Eucerin Photoacting Control Sun Anti Edad Fluído',
#      'results': 35},
#     {'id': 'MLA16048315',
#      'name': 'Protector solar Dermaglós FPS 50 FPS 50 en emulsión de 250 mL',
#      'results': 34},
#     {'id': 'MLA16048265',
#      'name': 'Protector Solar Dermaglós FPS50 Spray Continuo x170ml',
#      'results': 29},
#     {'id': 'MLA16048266',
#      'name': 'Dermaglós FPS 50 Invisible Spray continuo',
#      'results': 29},
#     {'id': 'MLA16048278',
#      'name': 'Protector solar Dermaglós FPS 80 FPS 80 en crema de 90 g',
#      'results': 27},
#     {'id': 'MLA16048279', 'name': 'Dermaglós FPS 80 Crema', 'results': 27},
#     {'id': 'MLA16048421',
#      'name': 'Dermaglós FPS 30 Emulsión - 30 - 250 mL',
#      'results': 27},
#     {'id': 'MLA16048398',
#      'name': 'Protector solar Dermaglós FPS 40 FPS 40 en spray continuo de 170 mL',
#      'results': 25},
#     {'id': 'MLA16048399',
#      'name': 'Dermaglós FPS 40 Spray continuo',
#      'results': 25},
#     {'id': 'MLA16048338',
#      'name': 'Eucerin Sun Protector Solar Fps 50 Pigment Control Fluid X50',
#      'results': 23},
#     {'id': 'MLA16048339',
#      'name': 'Eucerin Pigment Control Sun Fluído',
#      'results': 23},
#     {'id': 'MLA16048422',
#      'name': 'Protector solar Dermaglós FPS 30 FPS 30 Invisible en spray continuo de 170 mL',
#      'results': 23},
#     {'id': 'MLA16048423',
#      'name': 'Dermaglós FPS 30 Invisible Spray continuo',
#      'results': 23},
#     {'id': 'MLA16189495',
#      'name': 'Protector solar Dermaglós FPS 50 FPS 50 Con Color Tono Medio en crema de 50 g',
#      'results': 23},
#     {'id': 'MLA16189496',
#      'name': 'Dermaglós FPS 50 Con Color Tono Medio Crema',
#      'results': 23},
#     {'id': 'MLA16048342',
#      'name': 'Protector solar La Roche-Posay Anthelios XL FPS 50 en bruma de 200 mL',
#      'results': 22},
#     {'id': 'MLA16048343',
#      'name': 'La Roche-Posay Anthelios XL Bruma',
#      'results': 22},
#     {'id': 'MLA16048375',
#      'name': 'Dermaglós Niños FPS 50 Emulsión',
#      'results': 22},
#     {'id': 'MLA25903289',
#      'name': 'Eucerin Protector Solar Facial Hydro Fluid Fps50+ 50 Ml Eucerin PROTECCION SOLAR Hydro Fluid',
#      'results': 22},
#     {'id': 'MLA25903292',
#      'name': 'Eucerin Protector Solar Facial Hydro Fluid Fps50+ 50 Ml',
#      'results': 22},
#     {'id': 'MLA16048374',
#      'name': 'Protector solar Dermaglós Niños FPS 50 FPS 50 en emulsión de 180 mL',
#      'results': 21},
#     {'id': 'MLA19504443', 'name': 'Dermaglós Solar Crema', 'results': 21},
#     {'id': 'MLA19504472',
#      'name': 'Dermaglos Facial Fps50 Efecto Seco Invisible X 50 Gr',
#      'results': 21},
#     {'id': 'MLA19509037',
#      'name': 'La Roche Posay Anthelios Age Correct Fps50 Sin Color 50ml La Roche-Posay Anthelios Age Correct Crema',
#      'results': 20},
#     {'id': 'MLA19509065',
#      'name': 'La Roche Posay Anthelios Age Correct Fps50 Sin Color 50ml',
#      'results': 20},
#     {'id': 'MLA19638903',
#      'name': 'Anthelios Uvmune 400 Fluido Invisible50+ La Roche-posay 50ml La Roche-Posay Anthelios',
#      'results': 20},
#     {'id': 'MLA19638909',
#      'name': 'Anthelios Uvmune 400 Fluido Invisible50+ La Roche-posay 50ml',
#      'results': 20},
#     {'id': 'MLA19504447',
#      'name': 'Isdin Protector Solar Age Repair Fusion Water Fps50+ X 50 Ml Isdin Foto Ultra',
#      'results': 18},
#     {'id': 'MLA19504484',
#      'name': 'Isdin Protector Solar Age Repair Fusion Water Fps50+ X 50 Ml',
#      'results': 18},
#     {'id': 'MLA19509038',
#      'name': 'Eucerin Sun Fps 50 Oil Control Claro Toque Seco Facial X50ml Eucerin Oil Control Crema',
#      'results': 18},
#     {'id': 'MLA19509067',
#      'name': 'Eucerin Sun Fps 50 Oil Control Claro Toque Seco Facial X50ml',
#      'results': 18},
#     {'id': 'MLA16048275',
#      'name': 'Protector solar Eucerin Oil Control FPS 50 Toque Seco en gel crema de 50 mL',
#      'results': 17},
#     {'id': 'MLA19531201',
#      'name': 'Protector Solar Isdin Color Fps\xa050 En Crema 1 Unidad De 50\xa0ml 50\xa0g Isdin Color Crema',
#      'results': 17},
#     {'id': 'MLA19531221',
#      'name': 'Protector Solar Isdin Color Fps\xa050 En Crema 1 Unidad De 50\xa0ml 50\xa0g',
#      'results': 17},
#     {'id': 'MLA19638907',
#      'name': 'Fotocorrector La Roche-Posay anthelios oil correct 50 + spf 50ml para piel grasa anti-imperfecciones La Roche-Posay Anthelios Oil Correct Gel crema',
#      'results': 17},
#     {'id': 'MLA19638913',
#      'name': 'Anthelios Oil Correct Anti Acné Para Piel Grasa Fps 50 50 Ml',
#      'results': 17},
#     {'id': 'MLA16048231',
#      'name': 'Dermaglós Niños FPS 50 Spray continuo - 50 - 170 mL',
#      'results': 16},
#     {'id': 'MLA16048232',
#      'name': 'Dermaglós Niños FPS 50 Spray continuo',
#      'results': 16},
#     {'id': 'MLA19509035',
#      'name': 'Protector Solar Con Color Exel Facial Factor 60 Fps  X 50ml Exel Crema',
#      'results': 16},
#     {'id': 'MLA19509049',
#      'name': 'Protector Solar Lidherma Fps\xa040 En Crema 1 Unidad De 60\xa0ml 60\xa0g Lidherma Crema',
#      'results': 16},
#     {'id': 'MLA19509056',
#      'name': 'Protector Solar Con Color Exel Facial Factor 60 Fps  X 50ml',
#      'results': 16},
#     {'id': 'MLA19509089',
#      'name': 'Protector Solar Lidherma Fps\xa040 En Crema 1 Unidad De 60\xa0ml 60\xa0g',
#      'results': 16},
#     {'id': 'MLA16048424',
#      'name': 'Protector Solar Color Efecto Mate Anthelios Fps 50+ La Roche',
#      'results': 15},
#     {'id': 'MLA16048425',
#      'name': 'La Roche-Posay Anthelios XL Toque Seco con Color Pomo',
#      'results': 15}]},
#   {'id': 'official_store',
#    'name': 'Tiendas oficiales',
#    'type': 'text',
#    'values': [{'id': 'all',
#      'name': 'Todas las tiendas oficiales',
#      'results': 665},
#     {'id': '1859', 'name': 'Farmacias Selma', 'results': 187},
#     {'id': '3006', 'name': 'La Franco', 'results': 65},
#     {'id': '57706', 'name': 'Leloir Beauty Store', 'results': 18},
#     {'id': '2921', 'name': 'ALGABO', 'results': 17},
#     {'id': '2489', 'name': 'Farma Plus', 'results': 85},
#     {'id': '1469', 'name': 'Dermaglos', 'results': 36},
#     {'id': '1804', 'name': 'OPENFARMA', 'results': 15},
#     {'id': '2954', 'name': 'Mi Farma', 'results': 48},
#     {'id': '1742', 'name': 'Eucerin', 'results': 45},
#     {'id': '3101', 'name': 'Farmacias Central Oeste', 'results': 63},
#     {'id': '1105', 'name': 'Soy tu farmacia', 'results': 16},
#     {'id': '2336', 'name': 'Isdin', 'results': 5},
#     {'id': '1958', 'name': 'Clinique', 'results': 1}]}],
#  'pads_info': {'tracelog': ['mclics_off_cause=limit_zero;no_d2id;mclics_off']}}

# %%
# Para chequear haber hecho bien la busqueda inspeccionamos dentro del primer elemento
# del diccionario, en la variable 'results' y pedimos que nos brinde el título
data['results'][0]['title']

# Con el resultado vemos que hicimos bien la búsqueda
# Out:
# 'Protector Solar Dermaglós Fps 50 Fps 50 En Emulsión De 250 Ml'

# %% [markdown]
# #### Ejercicio 2
# Guarden los precios de los ítems obtenidos en un dataframe y calculen el precio promedio, el mínimo y el máximo.

# %%
# Importamos el módulo que requeriremos para hacer el dataframe y el histograma
import pandas as pd

# %%
# Creamos un dataframe que contiene dos columnas, una con el título de los productos y otra con los precios
precios_df = pd.DataFrame(columns=['Title', 'Price'])

# Armamos un loop que permitirá ir llenando el dataframe generado previamente con los productos obtenidos
for result in data['results']:
    precios_df = precios_df.append({'Title': result['title'], 'Price': result['price']}, ignore_index=True)
    
# Observamos los resultados   
print(precios_df)
# Out:
#                                                 Title     Price
# 0   Protector Solar Dermaglós Fps 50 Fps 50 En Emu...      8019
# 1   Dermaglos Facial Fps50 Efecto Seco Invisible X...      8846
# 2   Protector Solar Facial Eucerin Sun Fps 50+ Ton...     11542
# 3   Anthelios Uvmune 400 Fluido Invisible50+ La Ro...     12232
# 4   Isdin Fotoprotector Spf50+ Fusion Water Toque ...  15549.22
# 5   Fotoprotector Isdin Fusion Water Color Ligth  ...  16538.96
# 6   Protector Solar Dermaglós Fps 40 Fps 40 Efecto...      9190
# 7   Protector Solar Color Efecto Mate Anthelios Fp...     11017
# 8   Isdin Foto Ultra Active Unify Fusion Fluid Col...     20629
# 9   Fotoprotector Isdin Spf 50+ Gel Crema Protecto...     20487
# 10  Protector Solar Bronceador 8fps 250ml Cocoa Be...      4174
# 11  Dermaglós Solar Fps 40 Protección Alta X120ml ...      5695
# 12  Protector Solar Dermaglós Niños Fps 50 Fps 50 ...      7467
# 13  Cicatricure Protector Solar Fps 50 Antiage X 5...      5214
# 14  Protector Solar La Roche-posay Anthelios Xl Fp...     19380
# 15      Exel Pantalla Fotoprotectora Fps 60 Con Color      7300
# 16  Protector Solar Con Color Exel Facial Factor 6...      6210
# 17  Protector Solar Isdin Color Fps 50 En Crema 1 ...  16256.41
# 18     Protector Solar Dermaglós Fps50 Emulsión X50ml      2732
# 19    Protector Solar Dermaglós Fps40 Emulsión X250ml      7439
# 20  Isdin Fotoprotector Pediatrics Wet Skin Spf 50...     25476
# 21                  Cepage Filtres Fluide 50+ X 50 Ml    8612.2
# 22  Eucerin Protector Solar Facial Hydro Fluid Fps...     12524
# 23  Protector Solar Dermaglós Fps 80 Fps 80 En Cre...      9290
# 24           Protector Solar Fps 45 Cocoa Beach 130ml    3273.1
# 25  Rayito De Sol Bioactive Facial Protector Solar...      5733
# 26  Protector Solar Dermaglós Fps 50 Fps 50 Con Co...      7704
# 27  Protector Solar Dermaglós Fps 30 Fps 30 En Emu...  10283.57
# 28  Anthelios Oil Correct Anti Acné Para Piel Gras...     14568
# 29  Vichy Capital Soleil Fps50 Agua Protección Sol...     19595
# 30  Protector Solar Lidherma Fps 40 En Crema 1 Uni...   6653.88
# 31  La Roche Posay Anthelios Uv Mune 400 Crema Con...     12123
# 32  Caviahue Protector Solar Fps 50+  Gluten Free ...      7725
# 33  Isdin Protector Solar Age Repair Fusion Water ...   17116.9
# 34  Vichy Ideal Soleil Fps 30 Leche Beach Protect ...     18795
# 35  Lda Maprosol 50+ Emulsión Fluida Color 140ml P...  11634.91
# 36  Eucerin Solar Pigment Control Color Tono Medio...  14178.75
# 37  Protector Solar Vichy Idéal Soleil Fps 50 Spra...     20160
# 38  Protector Solar Dermaglós Fps50 Spray Continuo...      9362
# 39  Protector Solar Avène Fluido Fps 50 Ultra-mat ...     12875
# 40  Protector Solar Avène Fps 50 Crema En Tubo Dos...      9336
# 41  Eucerin Sun Fps50+ Gel-crema Corporal Toque Se...     11427
# 42  Protector Solar Facial Eucerin Sun Fps 50+ Ton...     12524
# 43  Dermaglós Solar Combo Protección Muy Alta Para...     31703
# 44  Protector Solar Lidherma Fps 50 En Crema 1 Uni...      6750
# 45  Dermaglós Protector Solar Fps65 Bebés +6 Meses...      8570
# 46  Eucerin Sun Oil Control Tinted Facial Tono Lig...  12525.75
# 47      Dermaglós Solar Fps 50 Emulsión - 50 - 380 Ml     10670
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4608\498957439.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': data['results'][elemento]['title'], 'Price': data['results'][elemento]['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4608\498957439.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': data['results'][elemento]['title'], 'Price': data['results'][elemento]['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4608\498957439.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': data['results'][elemento]['title'], 'Price': data['results'][elemento]['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4608\498957439.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': data['results'][elemento]['title'], 'Price': data['results'][elemento]['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4608\498957439.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': data['results'][elemento]['title'], 'Price': data['results'][elemento]['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4608\498957439.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': data['results'][elemento]['title'], 'Price': data['results'][elemento]['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4608\498957439.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': data['results'][elemento]['title'], 'Price': data['results'][elemento]['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4608\498957439.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': data['results'][elemento]['title'], 'Price': data['results'][elemento]['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4608\498957439.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': data['results'][elemento]['title'], 'Price': data['results'][elemento]['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4608\498957439.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': data['results'][elemento]['title'], 'Price': data['results'][elemento]['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4608\498957439.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': data['results'][elemento]['title'], 'Price': data['results'][elemento]['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4608\498957439.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': data['results'][elemento]['title'], 'Price': data['results'][elemento]['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4608\498957439.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': data['results'][elemento]['title'], 'Price': data['results'][elemento]['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4608\498957439.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': data['results'][elemento]['title'], 'Price': data['results'][elemento]['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4608\498957439.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': data['results'][elemento]['title'], 'Price': data['results'][elemento]['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4608\498957439.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': data['results'][elemento]['title'], 'Price': data['results'][elemento]['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4608\498957439.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': data['results'][elemento]['title'], 'Price': data['results'][elemento]['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4608\498957439.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': data['results'][elemento]['title'], 'Price': data['results'][elemento]['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4608\498957439.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': data['results'][elemento]['title'], 'Price': data['results'][elemento]['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4608\498957439.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': data['results'][elemento]['title'], 'Price': data['results'][elemento]['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4608\498957439.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': data['results'][elemento]['title'], 'Price': data['results'][elemento]['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4608\498957439.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': data['results'][elemento]['title'], 'Price': data['results'][elemento]['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4608\498957439.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': data['results'][elemento]['title'], 'Price': data['results'][elemento]['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4608\498957439.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': data['results'][elemento]['title'], 'Price': data['results'][elemento]['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4608\498957439.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': data['results'][elemento]['title'], 'Price': data['results'][elemento]['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4608\498957439.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': data['results'][elemento]['title'], 'Price': data['results'][elemento]['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4608\498957439.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': data['results'][elemento]['title'], 'Price': data['results'][elemento]['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4608\498957439.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': data['results'][elemento]['title'], 'Price': data['results'][elemento]['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4608\498957439.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': data['results'][elemento]['title'], 'Price': data['results'][elemento]['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4608\498957439.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': data['results'][elemento]['title'], 'Price': data['results'][elemento]['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4608\498957439.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': data['results'][elemento]['title'], 'Price': data['results'][elemento]['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4608\498957439.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': data['results'][elemento]['title'], 'Price': data['results'][elemento]['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4608\498957439.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': data['results'][elemento]['title'], 'Price': data['results'][elemento]['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4608\498957439.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': data['results'][elemento]['title'], 'Price': data['results'][elemento]['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4608\498957439.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': data['results'][elemento]['title'], 'Price': data['results'][elemento]['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4608\498957439.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': data['results'][elemento]['title'], 'Price': data['results'][elemento]['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4608\498957439.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': data['results'][elemento]['title'], 'Price': data['results'][elemento]['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4608\498957439.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': data['results'][elemento]['title'], 'Price': data['results'][elemento]['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4608\498957439.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': data['results'][elemento]['title'], 'Price': data['results'][elemento]['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4608\498957439.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': data['results'][elemento]['title'], 'Price': data['results'][elemento]['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4608\498957439.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': data['results'][elemento]['title'], 'Price': data['results'][elemento]['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4608\498957439.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': data['results'][elemento]['title'], 'Price': data['results'][elemento]['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4608\498957439.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': data['results'][elemento]['title'], 'Price': data['results'][elemento]['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4608\498957439.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': data['results'][elemento]['title'], 'Price': data['results'][elemento]['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4608\498957439.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': data['results'][elemento]['title'], 'Price': data['results'][elemento]['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4608\498957439.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': data['results'][elemento]['title'], 'Price': data['results'][elemento]['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4608\498957439.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': data['results'][elemento]['title'], 'Price': data['results'][elemento]['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4608\498957439.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': data['results'][elemento]['title'], 'Price': data['results'][elemento]['price']}, ignore_index=True)

# %%
# Calculamos el precio máximo, mínimo y promedio
precio_maximo = precios_df['Price'].max()
precio_minimo = precios_df['Price'].min()
precio_promedio = precios_df['Price'].mean()

# Observamos los resultados
print(f"Precio máximo: {precio_maximo}")
print(f"Precio mínimo: {precio_minimo}")
print(f"Precio promedio: {precio_promedio}")
# Out:
# Precio máximo: 31703
# Precio mínimo: 2732
# Precio promedio: 11814.721875000001

# %% [markdown]
# #### Ejercicio 3
# Armen un histograma de los precios. ¿Ven algún <i>outlier<i>?
# Nota: pueden usar la librería de Matplotlib o la de Pandas.

# %%
# Armamos un histograma de los precios
plt.hist(precios_df['Price'], bins=12, edgecolor='k') 

# Brindamos referencias para los ejes
plt.xlabel('Precio')
plt.ylabel('Frecuencia')
plt.title('Histograma de Precios')

# Ejecutamos el gráfico para que nos lo muestre
plt.show()

# %%
# Creamos el mismo histograma pero con más bins para ver si hay outliers
plt.hist(precios_df['Price'], bins=20, edgecolor='k') 
plt.xlabel('Precio')
plt.ylabel('Frecuencia')
plt.title('Histograma de Precios')
plt.show()

## Nota: parece haber algunos outliers en los precios por encima de 30K, la densidad se acumula entre 2K y 20K
