# %% [markdown]
# # Curso de Big Data
#
# ## Trabajo Práctico 1 - Parte 2
#
# ### Grupo: Armas Braithwaite, Fernández, Menta, Vargas Ochuza

# %% [markdown]
# ### Reglas de formato y presentación
# - El trabajo debe estar bien comentado (utilizando #) para que el código sea fácil de entender por sus compañeros y profesores.
#
# - El mismo debe ser completado en este Jupyter Notebook y entregado como tal, es decir en un archivo .ipynb

# %% [markdown]
# ### Fecha de entrega:
# Miércoles 4 de octubre a las 23:59hs

# %% [markdown]
# ### Modalidad de entrega
# - Al finalizar el trabajo práctico deben hacer un último <i>commit</i> en su repositorio de GitHub con el mensaje “Entrega final del tp”.
# - Asegurense de haber creado una carpeta llamada TP1. Este Jupyter Notebook y el correspondiente al TP1 - Parte 1 deben estar dentro de esa carpeta.
# - También deben completar el link de su repositorio -para que pueda ser clonado y corregido- en la siguiente google sheet: https://docs.google.com/spreadsheets/d/11nJY1Frgla45sTgsPiSeOZM9iBM-XRWh/edit?usp=sharing&ouid=105815768529474116534&rtpof=true&sd=true
# - La última versión en el repositorio es la que será evaluada. Por lo que es importante que:
#     - No completen la google sheet hasta no haber terminado y estar seguros de que han hecho el <i>commit y push</i> a la versión final que quieren entregar. Debido a que se pueden tomar hasta 3 días de extensión a lo largo del curso, no se  corregirán sus tareas hasta no ver el link en la google sheet.
#     - No hagan nuevos <i>push</i> despues de haber entregado su versión final. Esto generaría confusión acerca de que versión es la que quieren que se les corrija.

# %% [markdown]
# #### Ejercicio 1
# Usando la API de Mercado Libre, obtener los ítems de una consulta de búsqueda. Pueden buscar cualquier producto de su interés.

# %%
# Importamos los módulos necesarios para trabajar
import requests
import matplotlib.pyplot as plt

# %%
# Nuestro producto de interés será Protector Solar
buscar = "Protector Solar"

# Seguimos el formato que requiere la API donde adicionalmente indicamos que es MercadoLibre Argentina
url = "https://api.mercadolibre.com/sites/{}/search?q={}".format("MLA", buscar.replace(" ", "%20"))

# Hacemos el 'request' y obtenemos la 'response'
response = requests.request("GET", url)
print(response) 

# Vemos el texto
response.text

# Es importante hacer un comentario, por default la página de Mercadolibre nos trae 50 productos
# nosotros nos quedaremos con esta cantidad porque es así como lo vimos en la clase tutorial y a fines
# del procedimiento no cambia el código luego, pero si quisiesemos aumentar la cantidad de prodcutos luego de
# deberíamos modificar aquí la línea ".../sites/{}/search?q={}&limit=100..."
# Out:
# <Response [200]>
# '{"site_id":"MLA","country_default_time_zone":"GMT-03:00","query":"Protector Solar","paging":{"total":2978,"primary_results":1000,"offset":0,"limit":50},"results":[{"id":"MLA885797263","title":"Protector Solar Eucerin Oil Control Fps 50 Toque Seco En Gel Crema De 50 Ml","condition":"new","thumbnail_id":"838832-MLA44740439323_012021","catalog_product_id":"MLA16048275","listing_type_id":"gold_special","permalink":"https://www.mercadolibre.com.ar/protector-solar-eucerin-oil-control-fps-50-toque-seco-en-gel-crema-de-50-ml/p/MLA16048275","buying_mode":"buy_it_now","site_id":"MLA","category_id":"MLA392400","domain_id":"MLA-SUNSCREENS","thumbnail":"http://http2.mlstatic.com/D_838832-MLA44740439323_012021-I.jpg","currency_id":"ARS","order_backend":1,"price":11691,"original_price":16702,"sale_price":null,"sold_quantity":500,"available_quantity":1,"official_store_id":2251,"official_store_name":"Farmacity","use_thumbnail_id":true,"accepts_mercadopago":true,"tags":["good_quality_picture","brand_verified","good_quality_thumbnail","supermarket_eligible","immediate_payment","cart_eligible","best_seller_candidate","shipping_guaranteed"],"shipping":{"store_pick_up":false,"free_shipping":true,"logistic_type":"fulfillment","mode":"me2","tags":["fulfillment","MLA-CH-THRESHOLD-AGO-2023","mandatory_free_shipping"],"benefits":null,"promise":null},"stop_time":"2040-10-23T04:00:00.000Z","seller":{"id":610743463,"nickname":"FARMACITY_OFICIAL","car_dealer":false,"real_estate_agency":false,"_":false,"registration_date":"2020-07-16T14:57:08.000-04:00","tags":["brand","large_seller","credits_profile","messages_as_seller"],"car_dealer_logo":"","permalink":"http://perfil.mercadolibre.com.ar/FARMACITY_OFICIAL","seller_reputation":{"level_id":"5_green","power_seller_status":"platinum","transactions":{"canceled":11856,"completed":290777,"period":"historic","ratings":{"negative":0.09,"neutral":0.02,"positive":0.89},"total":302633},"metrics":{"sales":{"period":"60 days","completed":62182},"claims":{"period":"60 days","rate":0.0002,"value":17},"delayed_handling_time":{"period":"60 days","rate":0,"value":0},"cancellations":{"period":"60 days","rate":0,"value":0}}}},"seller_address":{"comment":"","address_line":"","id":null,"latitude":null,"longitude":null,"country":{"id":"AR","name":"Argentina"},"state":{"id":"AR-M","name":"Mendoza"},"city":{"id":"TUxBQ0NBUDFmNDY3","name":"Mendoza"}},"address":{"state_id":"AR-M","state_name":"Mendoza","city_id":"TUxBQ0NBUDFmNDY3","city_name":"Mendoza"},"attributes":[{"id":"BRAND","name":"Marca","value_id":"902988","value_name":"Eucerin","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":null,"values":[{"id":"902988","name":"Eucerin","struct":null,"source":1}],"source":1,"value_type":"string"},{"id":"ITEM_CONDITION","name":"Condición del ítem","value_id":"2230284","value_name":"Nuevo","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":null,"values":[{"id":"2230284","name":"Nuevo","struct":null,"source":1}],"source":1,"value_type":"list"},{"id":"LINE","name":"Línea","value_id":"8694441","value_name":"Oil Control","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":null,"values":[{"id":"8694441","name":"Oil Control","struct":null,"source":1}],"source":1,"value_type":"string"},{"id":"MODEL","name":"Modelo","value_id":"8694462","value_name":"Toque Seco","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":null,"values":[{"id":"8694462","name":"Toque Seco","struct":null,"source":1}],"source":1,"value_type":"string"},{"id":"NET_VOLUME","name":"Volumen neto","value_id":"112837","value_name":"50 mL","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":{"number":50,"unit":"mL"},"values":[{"id":"112837","name":"50 mL","struct":{"number":50,"unit":"mL"},"source":1}],"source":1,"value_type":"number_unit"},{"id":"PACKAGE_LENGTH","name":"Largo del paquete","value_id":null,"value_name":"12.2 cm","attribute_group_id":"OTHERS","att ...

# %%
# Guardamos el resultado en un diccionario, utilizamos Json debido a que es muy amigable para hacer estas tareas
# y le brinda una estructura util
data = response.json()

# obtenemos un diccionario denominado 'data'
data
# Out:
# {'site_id': 'MLA',
#  'country_default_time_zone': 'GMT-03:00',
#  'query': 'Protector Solar',
#  'paging': {'total': 2978, 'primary_results': 1000, 'offset': 0, 'limit': 50},
#  'results': [{'id': 'MLA885797263',
#    'title': 'Protector Solar Eucerin Oil Control Fps 50 Toque Seco En Gel Crema De 50 Ml',
#    'condition': 'new',
#    'thumbnail_id': '838832-MLA44740439323_012021',
#    'catalog_product_id': 'MLA16048275',
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://www.mercadolibre.com.ar/protector-solar-eucerin-oil-control-fps-50-toque-seco-en-gel-crema-de-50-ml/p/MLA16048275',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA392400',
#    'domain_id': 'MLA-SUNSCREENS',
#    'thumbnail': 'http://http2.mlstatic.com/D_838832-MLA44740439323_012021-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 1,
#    'price': 11691,
#    'original_price': 16702,
#    'sale_price': None,
#    'sold_quantity': 500,
#    'available_quantity': 1,
#    'official_store_id': 2251,
#    'official_store_name': 'Farmacity',
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'tags': ['good_quality_picture',
#     'brand_verified',
#     'good_quality_thumbnail',
#     'supermarket_eligible',
#     'immediate_payment',
#     'cart_eligible',
#     'best_seller_candidate',
#     'shipping_guaranteed'],
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'fulfillment',
#     'mode': 'me2',
#     'tags': ['fulfillment',
#      'MLA-CH-THRESHOLD-AGO-2023',
#      'mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2040-10-23T04:00:00.000Z',
#    'seller': {'id': 610743463,
#     'nickname': 'FARMACITY_OFICIAL',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     '_': False,
#     'registration_date': '2020-07-16T14:57:08.000-04:00',
#     'tags': ['brand', 'large_seller', 'credits_profile', 'messages_as_seller'],
#     'car_dealer_logo': '',
#     'permalink': 'http://perfil.mercadolibre.com.ar/FARMACITY_OFICIAL',
#     'seller_reputation': {'level_id': '5_green',
#      'power_seller_status': 'platinum',
#      'transactions': {'canceled': 11856,
#       'completed': 290777,
#       'period': 'historic',
#       'ratings': {'negative': 0.09, 'neutral': 0.02, 'positive': 0.89},
#       'total': 302633},
#      'metrics': {'sales': {'period': '60 days', 'completed': 62182},
#       'claims': {'period': '60 days', 'rate': 0.0002, 'value': 17},
#       'delayed_handling_time': {'period': '60 days', 'rate': 0, 'value': 0},
#       'cancellations': {'period': '60 days', 'rate': 0, 'value': 0}}}},
#    'seller_address': {'comment': '',
#     'address_line': '',
#     'id': None,
#     'latitude': None,
#     'longitude': None,
#     'country': {'id': 'AR', 'name': 'Argentina'},
#     'state': {'id': 'AR-M', 'name': 'Mendoza'},
#     'city': {'id': 'TUxBQ0NBUDFmNDY3', 'name': 'Mendoza'}},
#    'address': {'state_id': 'AR-M',
#     'state_name': 'Mendoza',
#     'city_id': 'TUxBQ0NBUDFmNDY3',
#     'city_name': 'Mendoza'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '902988',
#      'value_name': 'Eucerin',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '902988',
#        'name': 'Eucerin',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'LINE',
#      'name': 'Línea',
#      'value_id': '8694441',
#      'value_name': 'Oil Control',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '8694441',
#        'name': 'Oil Control',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '8694462',
#      'value_name': 'Toque Seco',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '8694462',
#        'name': 'Toque Seco',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'NET_VOLUME',
#      'name': 'Volumen neto',
#      'value_id': '112837',
#      'value_name': '50 mL',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 50, 'unit': 'mL'},
#      'values': [{'id': '112837',
#        'name': '50 mL',
#        'struct': {'number': 50, 'unit': 'mL'},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_LENGTH',
#      'name': 'Largo del paquete',
#      'value_id': None,
#      'value_name': '12.2 cm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 12.2, 'unit': 'cm'},
#      'values': [{'id': None,
#        'name': '12.2 cm',
#        'struct': {'unit': 'cm', 'number': 12.2},
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_WEIGHT',
#      'name': 'Peso del paquete',
#      'value_id': None,
#      'value_name': '80 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 80, 'unit': 'g'},
#      'values': [{'id': None,
#        'name': '80 g',
#        'struct': {'unit': 'g', 'number': 80},
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'number_unit'},
#     {'id': 'SALE_FORMAT',
#      'name': 'Formato de venta',
#      'value_id': '1359391',
#      'value_name': 'Unidad',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '1359391',
#        'name': 'Unidad',
#        'struct': None,
#        'source': 1138849081739375}],
#      'source': 1138849081739375,
#      'value_type': 'list'}],
#    'installments': {'quantity': 12,
#     'amount': 2197.91,
#     'rate': 125.6,
#     'currency_id': 'ARS'},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': 'QAGL21133'},
#   {'id': 'MLA1150055201',
#    'title': 'Dermaglos Facial Fps50 Efecto Seco Invisible X 50 Gr',
#    'condition': 'new',
#    'thumbnail_id': '701169-MLA50107987130_052022',
#    'catalog_product_id': 'MLA19504472',
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://www.mercadolibre.com.ar/dermaglos-facial-fps50-efecto-seco-invisible-x-50-gr/p/MLA19504472',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA392400',
#    'domain_id': 'MLA-SUNSCREENS',
#    'thumbnail': 'http://http2.mlstatic.com/D_701169-MLA50107987130_052022-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 2,
#    'price': 8846,
#    'original_price': 9833,
#    'sale_price': None,
#    'sold_quantity': 500,
#    'available_quantity': 500,
#    'official_store_id': 1859,
#    'official_store_name': 'Farmacias Selma',
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'tags': ['standard_price_by_channel',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'supermarket_eligible',
#     'immediate_payment',
#     'cart_eligible',
#     'best_seller_candidate',
#     'shipping_guaranteed'],
#    'shipping': {'store_pick_up': False,
#     'free_shipping': False,
#     'logistic_type': 'fulfillment',
#     'mode': 'me2',
#     'tags': ['fulfillment', 'self_service_out'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2042-07-31T04:00:00.000Z',
#    'seller': {'id': 377840555,
#     'nickname': 'FARMACIA SELMA',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     '_': False,
#     'registration_date': '2018-11-14T13:58:49.000-04:00',
#     'tags': ['brand',
#      'large_seller',
#      'eshop',
#      'mshops',
#      'credits_profile',
#      'messages_as_seller'],
#     'car_dealer_logo': '',
#     'permalink': 'http://perfil.mercadolibre.com.ar/FARMACIA+SELMA',
#     'seller_reputation': {'level_id': '5_green',
#      'power_seller_status': 'platinum',
#      'transactions': {'canceled': 22880,
#       'completed': 582530,
#       'period': 'historic',
#       'ratings': {'negative': 0.06, 'neutral': 0.02, 'positive': 0.92},
#       'total': 605410},
#      'metrics': {'sales': {'period': '60 days', 'completed': 134960},
#       'claims': {'period': '60 days', 'rate': 0.0026, 'value': 364},
#       'delayed_handling_time': {'period': '60 days',
#        'rate': 0.0015,
#        'value': 209},
#       'cancellations': {'period': '60 days', 'rate': 0.002, 'value': 292}}},
#     'eshop': {'eshop_id': 335554,
#      'seller': 377840555,
#      'nick_name': 'FARMACIA SELMA',
#      'eshop_status_id': 1,
#      'site_id': 'MLA',
#      'eshop_experience': 0,
#      'eshop_rubro': None,
#      'eshop_locations': [],
#      'eshop_logo_url': 'http://http2.mlstatic.com/eshops-logo/377840555ve918d7.png'}},
#    'seller_address': {'comment': '',
#     'address_line': '',
#     'id': None,
#     'latitude': None,
#     'longitude': None,
#     'country': {'id': 'AR', 'name': 'Argentina'},
#     'state': {'id': 'AR-B', 'name': 'Buenos Aires'},
#     'city': {'id': None, 'name': 'Olivos'}},
#    'address': {'state_id': 'AR-B',
#     'state_name': 'Buenos Aires',
#     'city_id': None,
#     'city_name': 'Olivos'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '968610',
#      'value_name': 'Dermaglós',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '968610',
#        'name': 'Dermaglós',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 2860837171021627}],
#      'source': 2860837171021627,
#      'value_type': 'list'},
#     {'id': 'LINE',
#      'name': 'Línea',
#      'value_id': '2124246',
#      'value_name': 'Solar',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2124246',
#        'name': 'Solar',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': None,
#      'value_name': 'Efecto Seco',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': 'Efecto Seco',
#        'struct': None,
#        'source': 2860837171021627}],
#      'source': 2860837171021627,
#      'value_type': 'string'},
#     {'id': 'NET_VOLUME',
#      'name': 'Volumen neto',
#      'value_id': None,
#      'value_name': '50 mL',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 50, 'unit': 'mL'},
#      'values': [{'id': None,
#        'name': '50 mL',
#        'struct': {'number': 50, 'unit': 'mL'},
#        'source': 2860837171021627}],
#      'source': 2860837171021627,
#      'value_type': 'number_unit'},
#     {'id': 'NET_WEIGHT',
#      'name': 'Peso neto',
#      'value_id': '135520',
#      'value_name': '50 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 50, 'unit': 'g'},
#      'values': [{'id': '135520',
#        'name': '50 g',
#        'struct': {'unit': 'g', 'number': 50},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_LENGTH',
#      'name': 'Largo del paquete',
#      'value_id': None,
#      'value_name': '14 cm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 14, 'unit': 'cm'},
#      'values': [{'id': None,
#        'name': '14 cm',
#        'struct': {'number': 14, 'unit': 'cm'},
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_WEIGHT',
#      'name': 'Peso del paquete',
#      'value_id': None,
#      'value_name': '100 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 100, 'unit': 'g'},
#      'values': [{'id': None,
#        'name': '100 g',
#        'struct': {'unit': 'g', 'number': 100},
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'number_unit'},
#     {'id': 'SALE_FORMAT',
#      'name': 'Formato de venta',
#      'value_id': '1359391',
#      'value_name': 'Unidad',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '1359391',
#        'name': 'Unidad',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'UNITS_PER_PACK',
#      'name': 'Unidades por pack',
#      'value_id': '2726554',
#      'value_name': '1',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2726554', 'name': '1', 'struct': None, 'source': 1}],
#      'source': 1,
#      'value_type': 'number'}],
#    'installments': {'quantity': 12,
#     'amount': 1663.05,
#     'rate': 125.6,
#     'currency_id': 'ARS'},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': 'XRMV02275'},
#   {'id': 'MLA901887785',
#    'title': 'Protector Solar Dermaglós Fps 30 Fps 30 En Emulsión De 380 Ml',
#    'condition': 'new',
#    'thumbnail_id': '722794-MLU71608459822_092023',
#    'catalog_product_id': 'MLA16251924',
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://www.mercadolibre.com.ar/protector-solar-dermaglos-fps-30-fps-30-en-emulsion-de-380-ml/p/MLA16251924',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA392400',
#    'domain_id': 'MLA-SUNSCREENS',
#    'thumbnail': 'http://http2.mlstatic.com/D_722794-MLU71608459822_092023-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 3,
#    'price': 9883.65,
#    'original_price': None,
#    'sale_price': None,
#    'sold_quantity': 50,
#    'available_quantity': 1,
#    'official_store_id': None,
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'tags': ['loyalty_discount_eligible',
#     'good_quality_thumbnail',
#     'good_quality_picture',
#     'supermarket_eligible',
#     'brand_verified',
#     'immediate_payment',
#     'cart_eligible',
#     'best_seller_candidate',
#     'shipping_guaranteed'],
#    'shipping': {'store_pick_up': False,
#     'free_shipping': False,
#     'logistic_type': 'fulfillment',
#     'mode': 'me2',
#     'tags': ['fulfillment', 'self_service_in'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2040-12-16T04:00:00.000Z',
#    'seller': {'id': 506786485,
#     'nickname': 'FARMACIA GENERALPAZ',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     '_': False,
#     'registration_date': '2019-12-26T10:37:45.000-04:00',
#     'tags': ['normal', 'credits_profile', 'mshops', 'messages_as_seller'],
#     'car_dealer_logo': '',
#     'permalink': 'http://perfil.mercadolibre.com.ar/FARMACIA+GENERALPAZ',
#     'seller_reputation': {'level_id': '5_green',
#      'power_seller_status': 'platinum',
#      'transactions': {'canceled': 2351,
#       'completed': 44505,
#       'period': 'historic',
#       'ratings': {'negative': 0.16, 'neutral': 0.01, 'positive': 0.83},
#       'total': 46856},
#      'metrics': {'sales': {'period': '60 days', 'completed': 7966},
#       'claims': {'period': '60 days', 'rate': 0.003, 'value': 25},
#       'delayed_handling_time': {'period': '60 days',
#        'rate': 0.0132,
#        'value': 106},
#       'cancellations': {'period': '60 days', 'rate': 0.003, 'value': 25}}}},
#    'seller_address': {'comment': '',
#     'address_line': '',
#     'id': None,
#     'latitude': None,
#     'longitude': None,
#     'country': {'id': 'AR', 'name': 'Argentina'},
#     'state': {'id': 'AR-X', 'name': 'Córdoba'},
#     'city': {'id': 'TUxBQ0NBUGNiZGQx', 'name': 'Córdoba'}},
#    'address': {'state_id': 'AR-X',
#     'state_name': 'Córdoba',
#     'city_id': 'TUxBQ0NBUGNiZGQx',
#     'city_name': 'Córdoba'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '968610',
#      'value_name': 'Dermaglós',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '968610',
#        'name': 'Dermaglós',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 6808261514773724}],
#      'source': 6808261514773724,
#      'value_type': 'list'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '8868320',
#      'value_name': 'FPS 30',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '8868320',
#        'name': 'FPS 30',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'NET_VOLUME',
#      'name': 'Volumen neto',
#      'value_id': '3890022',
#      'value_name': '380 mL',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 380, 'unit': 'mL'},
#      'values': [{'id': '3890022',
#        'name': '380 mL',
#        'struct': {'number': 380, 'unit': 'mL'},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_LENGTH',
#      'name': 'Largo del paquete',
#      'value_id': None,
#      'value_name': '6.4 cm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 6.4, 'unit': 'cm'},
#      'values': [{'id': None,
#        'name': '6.4 cm',
#        'struct': {'number': 6.4, 'unit': 'cm'},
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_WEIGHT',
#      'name': 'Peso del paquete',
#      'value_id': None,
#      'value_name': '440 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 440, 'unit': 'g'},
#      'values': [{'id': None,
#        'name': '440 g',
#        'struct': {'unit': 'g', 'number': 440},
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'number_unit'},
#     {'id': 'SALE_FORMAT',
#      'name': 'Formato de venta',
#      'value_id': '1359391',
#      'value_name': 'Unidad',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '1359391',
#        'name': 'Unidad',
#        'struct': None,
#        'source': 6808261514773724}],
#      'source': 6808261514773724,
#      'value_type': 'list'}],
#    'installments': {'quantity': 12,
#     'amount': 1858.13,
#     'rate': 125.6,
#     'currency_id': 'ARS'},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': 'DUYS50141'},
#   {'id': 'MLA1150388163',
#    'title': 'Isdin Protector Solar Age Repair Fusion Water Fps50+ X 50 Ml',
#    'condition': 'new',
#    'thumbnail_id': '817941-MLA49021733490_022022',
#    'catalog_product_id': 'MLA19504484',
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://www.mercadolibre.com.ar/isdin-protector-solar-age-repair-fusion-water-fps50-x-50-ml/p/MLA19504484',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA392400',
#    'domain_id': 'MLA-SUNSCREENS',
#    'thumbnail': 'http://http2.mlstatic.com/D_817941-MLA49021733490_022022-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 4,
#    'price': 19649,
#    'original_price': 22252,
#    'sale_price': None,
#    'sold_quantity': 150,
#    'available_quantity': 200,
#    'official_store_id': 1859,
#    'official_store_name': 'Farmacias Selma',
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'tags': ['brand_verified',
#     'standard_price_by_channel',
#     'good_quality_picture',
#     'deal_of_the_day',
#     'good_quality_thumbnail',
#     'immediate_payment',
#     'cart_eligible',
#     'best_seller_candidate',
#     'shipping_guaranteed'],
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'cross_docking',
#     'mode': 'me2',
#     'tags': ['MLA-chg-threshold-Feb-23',
#      'self_service_in',
#      'mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2042-08-01T04:00:00.000Z',
#    'seller': {'id': 377840555,
#     'nickname': 'FARMACIA SELMA',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     '_': False,
#     'registration_date': '2018-11-14T13:58:49.000-04:00',
#     'tags': ['brand',
#      'large_seller',
#      'eshop',
#      'mshops',
#      'credits_profile',
#      'messages_as_seller'],
#     'car_dealer_logo': '',
#     'permalink': 'http://perfil.mercadolibre.com.ar/FARMACIA+SELMA',
#     'seller_reputation': {'level_id': '5_green',
#      'power_seller_status': 'platinum',
#      'transactions': {'canceled': 22880,
#       'completed': 582530,
#       'period': 'historic',
#       'ratings': {'negative': 0.06, 'neutral': 0.02, 'positive': 0.92},
#       'total': 605410},
#      'metrics': {'sales': {'period': '60 days', 'completed': 134960},
#       'claims': {'period': '60 days', 'rate': 0.0026, 'value': 364},
#       'delayed_handling_time': {'period': '60 days',
#        'rate': 0.0015,
#        'value': 209},
#       'cancellations': {'period': '60 days', 'rate': 0.002, 'value': 292}}},
#     'eshop': {'eshop_id': 335554,
#      'seller': 377840555,
#      'nick_name': 'FARMACIA SELMA',
#      'eshop_status_id': 1,
#      'site_id': 'MLA',
#      'eshop_experience': 0,
#      'eshop_rubro': None,
#      'eshop_locations': [],
#      'eshop_logo_url': 'http://http2.mlstatic.com/eshops-logo/377840555ve918d7.png'}},
#    'seller_address': {'comment': '',
#     'address_line': '',
#     'id': None,
#     'latitude': None,
#     'longitude': None,
#     'country': {'id': 'AR', 'name': 'Argentina'},
#     'state': {'id': 'AR-B', 'name': 'Buenos Aires'},
#     'city': {'id': None, 'name': 'Olivos'}},
#    'address': {'state_id': 'AR-B',
#     'state_name': 'Buenos Aires',
#     'city_id': None,
#     'city_name': 'Olivos'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '1134713',
#      'value_name': 'Isdin',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '1134713',
#        'name': 'Isdin',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 1572}],
#      'source': 1572,
#      'value_type': 'list'},
#     {'id': 'LINE',
#      'name': 'Línea',
#      'value_id': '9571532',
#      'value_name': 'Foto Ultra',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '9571532',
#        'name': 'Foto Ultra',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '8712192',
#      'value_name': 'Age Repair',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '8712192',
#        'name': 'Age Repair',
#        'struct': None,
#        'source': 1000427007642219}],
#      'source': 1000427007642219,
#      'value_type': 'string'},
#     {'id': 'NET_VOLUME',
#      'name': 'Volumen neto',
#      'value_id': '112837',
#      'value_name': '50 mL',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 50, 'unit': 'mL'},
#      'values': [{'id': '112837',
#        'name': '50 mL',
#        'struct': {'number': 50, 'unit': 'mL'},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'},
#     {'id': 'NET_WEIGHT',
#      'name': 'Peso neto',
#      'value_id': None,
#      'value_name': '50 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 50, 'unit': 'g'},
#      'values': [{'id': None,
#        'name': '50 g',
#        'struct': {'number': 50, 'unit': 'g'},
#        'source': 3376461333454861}],
#      'source': 3376461333454861,
#      'value_type': 'number_unit'},
#     {'id': 'SALE_FORMAT',
#      'name': 'Formato de venta',
#      'value_id': '1359391',
#      'value_name': 'Unidad',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '1359391',
#        'name': 'Unidad',
#        'struct': None,
#        'source': 3376461333454861}],
#      'source': 3376461333454861,
#      'value_type': 'list'}],
#    'installments': {'quantity': 12,
#     'amount': 3694.01,
#     'rate': 125.6,
#     'currency_id': 'ARS'},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': None},
#   {'id': 'MLA1249309173',
#    'title': 'Umbrella Intelligent Protector Solar Spf 99 50grs',
#    'condition': 'new',
#    'thumbnail_id': '723518-MLA51602568589_092022',
#    'catalog_product_id': 'MLA19734164',
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://www.mercadolibre.com.ar/umbrella-intelligent-protector-solar-spf-99-50grs/p/MLA19734164',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA392400',
#    'domain_id': 'MLA-SUNSCREENS',
#    'thumbnail': 'http://http2.mlstatic.com/D_723518-MLA51602568589_092022-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 5,
#    'price': 13490.18,
#    'original_price': None,
#    'sale_price': None,
#    'sold_quantity': 100,
#    'available_quantity': 1,
#    'official_store_id': None,
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'tags': ['good_quality_thumbnail',
#     'good_quality_picture',
#     'moderation_penalty',
#     'brand_verified',
#     'immediate_payment',
#     'cart_eligible',
#     'shipping_guaranteed'],
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'cross_docking',
#     'mode': 'me2',
#     'tags': ['MLA-CH-THRESHOLD-AGO-2023',
#      'self_service_in',
#      'mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2042-11-13T04:00:00.000Z',
#    'seller': {'id': 313043158,
#     'nickname': 'FARMABELÉN',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     '_': False,
#     'registration_date': '2018-04-06T19:11:23.000-04:00',
#     'tags': ['normal',
#      'eshop',
#      'mshops',
#      'credits_profile',
#      'messages_as_seller'],
#     'car_dealer_logo': '',
#     'permalink': 'http://perfil.mercadolibre.com.ar/FARMABELEN.',
#     'seller_reputation': {'level_id': '5_green',
#      'power_seller_status': 'platinum',
#      'transactions': {'canceled': 6126,
#       'completed': 136913,
#       'period': 'historic',
#       'ratings': {'negative': 0.04, 'neutral': 0.02, 'positive': 0.94},
#       'total': 143039},
#      'metrics': {'sales': {'period': '60 days', 'completed': 32587},
#       'claims': {'period': '60 days', 'rate': 0.0032, 'value': 109},
#       'delayed_handling_time': {'period': '60 days',
#        'rate': 0.0089,
#        'value': 289},
#       'cancellations': {'period': '60 days', 'rate': 0.0015, 'value': 53}}},
#     'eshop': {'eshop_id': 424614,
#      'seller': 313043158,
#      'nick_name': 'FARMABELÉN',
#      'eshop_status_id': 1,
#      'site_id': 'MLA',
#      'eshop_experience': 0,
#      'eshop_rubro': None,
#      'eshop_locations': [],
#      'eshop_logo_url': 'http://http2.mlstatic.com/eshops-logo/313043158vfe8a79.png'}},
#    'seller_address': {'comment': '',
#     'address_line': '',
#     'id': None,
#     'latitude': None,
#     'longitude': None,
#     'country': {'id': 'AR', 'name': 'Argentina'},
#     'state': {'id': 'AR-C', 'name': 'Capital Federal'},
#     'city': {'id': 'TUxBQlZJTDQ4MzBa', 'name': 'Villa Lugano'}},
#    'address': {'state_id': 'AR-C',
#     'state_name': 'Capital Federal',
#     'city_id': 'TUxBQlZJTDQ4MzBa',
#     'city_name': 'Villa Lugano'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '13389404',
#      'value_name': 'Umbrella Intelligent',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '13389404',
#        'name': 'Umbrella Intelligent',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 6808261514773724}],
#      'source': 6808261514773724,
#      'value_type': 'list'},
#     {'id': 'LINE',
#      'name': 'Línea',
#      'value_id': '-1',
#      'value_name': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '-1',
#        'name': None,
#        'struct': None,
#        'source': 3376461333454861}],
#      'source': 3376461333454861,
#      'value_type': 'string'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '13389406',
#      'value_name': 'Umbrella Intelligent',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '13389406',
#        'name': 'Umbrella Intelligent',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'NET_VOLUME',
#      'name': 'Volumen neto',
#      'value_id': None,
#      'value_name': '50 mL',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 50, 'unit': 'mL'},
#      'values': [{'id': None,
#        'name': '50 mL',
#        'struct': {'number': 50, 'unit': 'mL'},
#        'source': 6808261514773724}],
#      'source': 6808261514773724,
#      'value_type': 'number_unit'},
#     {'id': 'NET_WEIGHT',
#      'name': 'Peso neto',
#      'value_id': '135520',
#      'value_name': '50 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 50, 'unit': 'g'},
#      'values': [{'id': '135520',
#        'name': '50 g',
#        'struct': {'unit': 'g', 'number': 50},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'},
#     {'id': 'SALE_FORMAT',
#      'name': 'Formato de venta',
#      'value_id': '1359391',
#      'value_name': 'Unidad',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '1359391',
#        'name': 'Unidad',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'UNITS_PER_PACK',
#      'name': 'Unidades por pack',
#      'value_id': '2726554',
#      'value_name': '1',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2726554', 'name': '1', 'struct': None, 'source': 1}],
#      'source': 1,
#      'value_type': 'number'}],
#    'installments': {'quantity': 12,
#     'amount': 2536.15,
#     'rate': 125.6,
#     'currency_id': 'ARS'},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': None},
#   {'id': 'MLA1387561447',
#    'title': 'Protector Solar Dermaglós Fps 50 Fps 50 En Emulsión De 250 Ml',
#    'condition': 'new',
#    'thumbnail_id': '641809-MLA44740405275_012021',
#    'catalog_product_id': 'MLA16048315',
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://www.mercadolibre.com.ar/protector-solar-dermaglos-fps-50-fps-50-en-emulsion-de-250-ml/p/MLA16048315',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA392400',
#    'domain_id': 'MLA-SUNSCREENS',
#    'thumbnail': 'http://http2.mlstatic.com/D_641809-MLA44740405275_012021-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 6,
#    'price': 7145,
#    'original_price': 10028,
#    'sale_price': None,
#    'sold_quantity': 250,
#    'available_quantity': 500,
#    'official_store_id': 1804,
#    'official_store_name': 'OPENFARMA',
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'tags': ['good_quality_thumbnail',
#     'deal_of_the_day',
#     'immediate_payment',
#     'cart_eligible',
#     'best_seller_candidate',
#     'shipping_guaranteed'],
#    'shipping': {'store_pick_up': False,
#     'free_shipping': False,
#     'logistic_type': 'cross_docking',
#     'mode': 'me2',
#     'tags': ['self_service_in'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2043-09-06T04:00:00.000Z',
#    'seller': {'id': 320396604,
#     'nickname': 'OPENFARMA',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     '_': False,
#     'registration_date': '2018-05-09T11:41:20.000-04:00',
#     'tags': ['brand', 'large_seller', 'credits_profile', 'messages_as_seller'],
#     'car_dealer_logo': '',
#     'permalink': 'http://perfil.mercadolibre.com.ar/OPENFARMA',
#     'seller_reputation': {'level_id': '5_green',
#      'power_seller_status': 'platinum',
#      'transactions': {'canceled': 5465,
#       'completed': 127268,
#       'period': 'historic',
#       'ratings': {'negative': 0.05, 'neutral': 0.03, 'positive': 0.92},
#       'total': 132733},
#      'metrics': {'sales': {'period': '60 days', 'completed': 23804},
#       'claims': {'period': '60 days', 'rate': 0.0042, 'value': 106},
#       'delayed_handling_time': {'period': '60 days',
#        'rate': 0.0234,
#        'value': 537},
#       'cancellations': {'period': '60 days', 'rate': 0.0025, 'value': 64}}}},
#    'seller_address': {'comment': '',
#     'address_line': '',
#     'id': None,
#     'latitude': None,
#     'longitude': None,
#     'country': {'id': 'AR', 'name': 'Argentina'},
#     'state': {'id': 'AR-C', 'name': 'Capital Federal'},
#     'city': {'id': 'TUxBQkNBQjM4MDda', 'name': 'Caballito'}},
#    'address': {'state_id': 'AR-C',
#     'state_name': 'Capital Federal',
#     'city_id': 'TUxBQkNBQjM4MDda',
#     'city_name': 'Caballito'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '968610',
#      'value_name': 'Dermaglós',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '968610',
#        'name': 'Dermaglós',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 1138849081739375}],
#      'source': 1138849081739375,
#      'value_type': 'list'},
#     {'id': 'LINE',
#      'name': 'Línea',
#      'value_id': '2124246',
#      'value_name': 'Solar',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2124246',
#        'name': 'Solar',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '8868325',
#      'value_name': 'FPS 50',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '8868325',
#        'name': 'FPS 50',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'NET_VOLUME',
#      'name': 'Volumen neto',
#      'value_id': '127299',
#      'value_name': '250 mL',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 250, 'unit': 'mL'},
#      'values': [{'id': '127299',
#        'name': '250 mL',
#        'struct': {'number': 250, 'unit': 'mL'},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'},
#     {'id': 'SALE_FORMAT',
#      'name': 'Formato de venta',
#      'value_id': '1359391',
#      'value_name': 'Unidad',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '1359391',
#        'name': 'Unidad',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'UNITS_PER_PACK',
#      'name': 'Unidades por pack',
#      'value_id': '2726554',
#      'value_name': '1',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2726554', 'name': '1', 'struct': None, 'source': 1}],
#      'source': 1,
#      'value_type': 'number'}],
#    'installments': {'quantity': 12,
#     'amount': 1343.26,
#     'rate': 125.6,
#     'currency_id': 'ARS'},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': None},
#   {'id': 'MLA1173602337',
#    'title': 'Isdin Fotoprotector Spf50+ Fusion Water Toque Seco X 50 Ml',
#    'condition': 'new',
#    'thumbnail_id': '790529-MLA53244254168_012023',
#    'catalog_product_id': 'MLA19509077',
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://www.mercadolibre.com.ar/isdin-fotoprotector-spf50-fusion-water-toque-seco-x-50-ml/p/MLA19509077',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA392400',
#    'domain_id': 'MLA-SUNSCREENS',
#    'thumbnail': 'http://http2.mlstatic.com/D_790529-MLA53244254168_012023-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 7,
#    'price': 14701,
#    'original_price': None,
#    'sale_price': None,
#    'sold_quantity': 500,
#    'available_quantity': 250,
#    'official_store_id': 2489,
#    'official_store_name': 'Farma Plus',
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'tags': ['good_quality_picture',
#     'good_quality_thumbnail',
#     'immediate_payment',
#     'cart_eligible',
#     'best_seller_candidate'],
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'cross_docking',
#     'mode': 'me2',
#     'tags': ['self_service_in', 'mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2042-09-16T04:00:00.000Z',
#    'seller': {'id': 802641616,
#     'nickname': 'FARMAPLUS2',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     '_': False,
#     'registration_date': '2021-08-05T12:14:16.000-04:00',
#     'tags': ['brand', 'large_seller', 'credits_profile', 'messages_as_seller'],
#     'car_dealer_logo': '',
#     'permalink': 'http://perfil.mercadolibre.com.ar/FARMAPLUS2',
#     'seller_reputation': {'level_id': '5_green',
#      'power_seller_status': 'platinum',
#      'transactions': {'canceled': 2018,
#       'completed': 35570,
#       'period': 'historic',
#       'ratings': {'negative': 0.1, 'neutral': 0.04, 'positive': 0.86},
#       'total': 37588},
#      'metrics': {'sales': {'period': '60 days', 'completed': 9872},
#       'claims': {'period': '60 days', 'rate': 0.009, 'value': 94},
#       'delayed_handling_time': {'period': '60 days',
#        'rate': 0.0548,
#        'value': 543},
#       'cancellations': {'period': '60 days', 'rate': 0.0045, 'value': 47}}}},
#    'seller_address': {'comment': '',
#     'address_line': '',
#     'id': None,
#     'latitude': None,
#     'longitude': None,
#     'country': {'id': 'AR', 'name': 'Argentina'},
#     'state': {'id': 'AR-C', 'name': 'Capital Federal'},
#     'city': {'id': 'TUxBQkJBUjM0MDha', 'name': 'Barracas'}},
#    'address': {'state_id': 'AR-C',
#     'state_name': 'Capital Federal',
#     'city_id': 'TUxBQkJBUjM0MDha',
#     'city_name': 'Barracas'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '1134713',
#      'value_name': 'Isdin',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '1134713',
#        'name': 'Isdin',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 3045741222775799}],
#      'source': 3045741222775799,
#      'value_type': 'list'},
#     {'id': 'LINE',
#      'name': 'Línea',
#      'value_id': '3416010',
#      'value_name': 'Fotoprotector',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '3416010',
#        'name': 'Fotoprotector',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '8712197',
#      'value_name': 'Fusion Water',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '8712197',
#        'name': 'Fusion Water',
#        'struct': None,
#        'source': 3045741222775799}],
#      'source': 3045741222775799,
#      'value_type': 'string'},
#     {'id': 'NET_VOLUME',
#      'name': 'Volumen neto',
#      'value_id': '112837',
#      'value_name': '50 mL',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 50, 'unit': 'mL'},
#      'values': [{'id': '112837',
#        'name': '50 mL',
#        'struct': {'unit': 'mL', 'number': 50},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'},
#     {'id': 'SALE_FORMAT',
#      'name': 'Formato de venta',
#      'value_id': '1359391',
#      'value_name': 'Unidad',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '1359391',
#        'name': 'Unidad',
#        'struct': None,
#        'source': 3045741222775799}],
#      'source': 3045741222775799,
#      'value_type': 'list'},
#     {'id': 'UNITS_PER_PACK',
#      'name': 'Unidades por pack',
#      'value_id': None,
#      'value_name': '1',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': '1',
#        'struct': None,
#        'source': 2579503448603610}],
#      'source': 2579503448603610,
#      'value_type': 'number'}],
#    'installments': {'quantity': 12,
#     'amount': 2763.79,
#     'rate': 125.6,
#     'currency_id': 'ARS'},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': None},
#   {'id': 'MLA1181877593',
#    'title': 'Anthelios Uvmune 400 Fluido Invisible50+ La Roche-posay 50ml',
#    'condition': 'new',
#    'thumbnail_id': '966734-MLA51230469218_082022',
#    'catalog_product_id': 'MLA19638909',
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://www.mercadolibre.com.ar/anthelios-uvmune-400-fluido-invisible50-la-roche-posay-50ml/p/MLA19638909',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA392400',
#    'domain_id': 'MLA-SUNSCREENS',
#    'thumbnail': 'http://http2.mlstatic.com/D_966734-MLA51230469218_082022-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 8,
#    'price': 12232,
#    'original_price': 16310,
#    'sale_price': None,
#    'sold_quantity': 500,
#    'available_quantity': 500,
#    'official_store_id': 1859,
#    'official_store_name': 'Farmacias Selma',
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'tags': ['good_quality_thumbnail',
#     'standard_price_by_channel',
#     'good_quality_picture',
#     'immediate_payment',
#     'cart_eligible',
#     'best_seller_candidate',
#     'shipping_guaranteed'],
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'cross_docking',
#     'mode': 'me2',
#     'tags': ['MLA-chg-threshold-Feb-23',
#      'self_service_in',
#      'mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2043-04-28T14:04:01.000Z',
#    'seller': {'id': 377840555,
#     'nickname': 'FARMACIA SELMA',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     '_': False,
#     'registration_date': '2018-11-14T13:58:49.000-04:00',
#     'tags': ['brand',
#      'large_seller',
#      'eshop',
#      'mshops',
#      'credits_profile',
#      'messages_as_seller'],
#     'car_dealer_logo': '',
#     'permalink': 'http://perfil.mercadolibre.com.ar/FARMACIA+SELMA',
#     'seller_reputation': {'level_id': '5_green',
#      'power_seller_status': 'platinum',
#      'transactions': {'canceled': 22880,
#       'completed': 582530,
#       'period': 'historic',
#       'ratings': {'negative': 0.06, 'neutral': 0.02, 'positive': 0.92},
#       'total': 605410},
#      'metrics': {'sales': {'period': '60 days', 'completed': 134960},
#       'claims': {'period': '60 days', 'rate': 0.0026, 'value': 364},
#       'delayed_handling_time': {'period': '60 days',
#        'rate': 0.0015,
#        'value': 209},
#       'cancellations': {'period': '60 days', 'rate': 0.002, 'value': 292}}},
#     'eshop': {'eshop_id': 335554,
#      'seller': 377840555,
#      'nick_name': 'FARMACIA SELMA',
#      'eshop_status_id': 1,
#      'site_id': 'MLA',
#      'eshop_experience': 0,
#      'eshop_rubro': None,
#      'eshop_locations': [],
#      'eshop_logo_url': 'http://http2.mlstatic.com/eshops-logo/377840555ve918d7.png'}},
#    'seller_address': {'comment': '',
#     'address_line': '',
#     'id': None,
#     'latitude': None,
#     'longitude': None,
#     'country': {'id': 'AR', 'name': 'Argentina'},
#     'state': {'id': 'AR-B', 'name': 'Buenos Aires'},
#     'city': {'id': None, 'name': 'Olivos'}},
#    'address': {'state_id': 'AR-B',
#     'state_name': 'Buenos Aires',
#     'city_id': None,
#     'city_name': 'Olivos'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '1515703',
#      'value_name': 'La Roche-Posay',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '1515703',
#        'name': 'La Roche-Posay',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'LINE',
#      'name': 'Línea',
#      'value_id': '8694443',
#      'value_name': 'Anthelios',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '8694443',
#        'name': 'Anthelios',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': None,
#      'value_name': 'Anthelios Uv Mune Fluido Invisible',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': 'Anthelios Uv Mune Fluido Invisible',
#        'struct': None,
#        'source': 3376461333454861}],
#      'source': 3376461333454861,
#      'value_type': 'string'},
#     {'id': 'NET_VOLUME',
#      'name': 'Volumen neto',
#      'value_id': '112837',
#      'value_name': '50 mL',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 50, 'unit': 'mL'},
# ...
#     {'id': '5752495', 'name': 'Lure', 'results': 4},
#     {'id': '428924', 'name': 'Cetaphil', 'results': 4},
#     {'id': '24179', 'name': 'Yanbal', 'results': 4},
#     {'id': '182722', 'name': 'Ozone', 'results': 4},
#     {'id': '13912112', 'name': 'Cassara', 'results': 4},
#     {'id': '13798346', 'name': 'Brown Bee', 'results': 4},
#     {'id': '13389404', 'name': 'Umbrella Intelligent', 'results': 4},
#     {'id': '8694794', 'name': 'Algabo', 'results': 3},
#     {'id': '6994122', 'name': "A'pieu", 'results': 3},
#     {'id': '428925', 'name': 'Cicatricure', 'results': 3},
#     {'id': '2766664', 'name': 'Arvensis', 'results': 3},
#     {'id': '23130', 'name': 'O Boticário', 'results': 3},
#     {'id': '13407931', 'name': 'Umbrella', 'results': 3},
#     {'id': '12964724', 'name': 'La Roche Posay', 'results': 3},
#     {'id': '11874145', 'name': 'Nivea Sun', 'results': 3},
#     {'id': '968593', 'name': "Fiorel'a", 'results': 2},
#     {'id': '7236006', 'name': 'Triumph & Disaster', 'results': 2},
#     {'id': '6875099', 'name': 'Dermaprof', 'results': 2},
#     {'id': '6110178', 'name': 'Coolibar', 'results': 2},
#     {'id': '428935', 'name': 'Neutrogena', 'results': 2},
#     {'id': '3764968', 'name': 'Las Margaritas', 'results': 2},
#     {'id': '3453779', 'name': 'The Ordinary', 'results': 2},
#     {'id': '2899746', 'name': 'Poseidon', 'results': 2},
#     {'id': '2671247', 'name': 'Bagués', 'results': 2},
#     {'id': '2645264', 'name': 'Selecta', 'results': 2},
#     {'id': '2531683', 'name': 'GH', 'results': 2},
#     {'id': '24052', 'name': 'Biotherm', 'results': 2},
#     {'id': '2305581', 'name': 'Fórmula Dra. Norma Bustos', 'results': 2},
#     {'id': '21708150', 'name': 'CVS', 'results': 2},
#     {'id': '15119343', 'name': 'Novaderma', 'results': 2},
#     {'id': '13914813', 'name': 'Emynent', 'results': 2},
#     {'id': '13804823', 'name': 'Avene Eau Thermale', 'results': 2},
#     {'id': '13429130', 'name': 'Sun Bum', 'results': 2},
#     {'id': '13393994', 'name': 'Elta Md', 'results': 2},
#     {'id': '12931769', 'name': 'Andrómaco', 'results': 2},
#     {'id': '1220699', 'name': "L'Oréal Paris", 'results': 2},
#     {'id': '11042411', 'name': 'Heliocare', 'results': 2},
#     {'id': '1060196', 'name': 'Kaori', 'results': 2},
#     {'id': '968590', 'name': 'Zine', 'results': 1},
#     {'id': '9543388', 'name': 'Natureza', 'results': 1},
#     {'id': '898841', 'name': 'Venum', 'results': 1},
#     {'id': '5006312', 'name': 'Natufarma', 'results': 1},
#     {'id': '4965190', 'name': 'Pharmatrix', 'results': 1},
#     {'id': '3917351', 'name': 'Ringside', 'results': 1},
#     {'id': '3813571', 'name': 'H&G', 'results': 1},
#     {'id': '3759492', 'name': 'Bioré', 'results': 1},
#     {'id': '3334896', 'name': 'Tierras del Volcán', 'results': 1},
#     {'id': '2955496', 'name': 'Banana Boat', 'results': 1},
#     {'id': '2897433', 'name': 'La Mer', 'results': 1},
#     {'id': '2720789', 'name': 'CeraVe', 'results': 1},
#     {'id': '2707209', 'name': 'Murad', 'results': 1},
#     {'id': '2642729', 'name': 'Innisfree', 'results': 1},
#     {'id': '2642690', 'name': 'Arex', 'results': 1},
#     {'id': '250226', 'name': 'Amodil', 'results': 1},
#     {'id': '2500208', 'name': 'Laura Mercier', 'results': 1},
#     {'id': '249084', 'name': 'Monique Arnold', 'results': 1},
#     {'id': '23748', 'name': 'Millanel', 'results': 1},
#     {'id': '23662', 'name': 'Estée Lauder', 'results': 1},
#     {'id': '23255', 'name': 'Guerlain', 'results': 1},
#     {'id': '2310276', 'name': 'Forever Living', 'results': 1},
#     {'id': '23057', 'name': 'Givenchy', 'results': 1},
#     {'id': '23042', 'name': 'Lancôme', 'results': 1},
#     {'id': '22982', 'name': 'Sisley', 'results': 1},
#     {'id': '2136629', 'name': 'Seytú', 'results': 1},
#     {'id': '19163495', 'name': 'Oficinalis', 'results': 1},
#     {'id': '17612231', 'name': 'Skin1004', 'results': 1},
#     {'id': '16490574', 'name': 'Drmtlgy', 'results': 1},
#     {'id': '13765820', 'name': 'Neogen', 'results': 1},
#     {'id': '13759627', 'name': 'Vansame', 'results': 1},
#     {'id': '13629817', 'name': 'Anthelios', 'results': 1},
#     {'id': '13074490', 'name': 'Crembel', 'results': 1},
#     {'id': '12947887', 'name': 'Cosrx', 'results': 1},
#     {'id': '12902213', 'name': 'Vida Natural', 'results': 1},
#     {'id': '12901792', 'name': 'Milaborit', 'results': 1},
#     {'id': '1262696', 'name': 'Biocom', 'results': 1},
#     {'id': '12472438', 'name': 'LRP', 'results': 1},
#     {'id': '12355446', 'name': 'Openfarma', 'results': 1},
#     {'id': '12355403', 'name': 'Dr. Duval', 'results': 1},
#     {'id': '12355391', 'name': 'Collage', 'results': 1},
#     {'id': '1162050', 'name': 'Missha', 'results': 1}]},
#   {'id': 'IS_CRUELTY_FREE',
#    'name': 'Otras características',
#    'type': 'boolean',
#    'values': [{'id': '242085',
#      'name': 'Es libre de crueldad',
#      'results': 1200}]},
#   {'id': 'IS_GLUTEN_FREE',
#    'name': 'Otras características',
#    'type': 'boolean',
#    'values': [{'id': '242085', 'name': 'Es libre de gluten', 'results': 870}]},
#   {'id': 'IS_HYPOALLERGENIC_PRODUCT',
#    'name': 'Otras características',
#    'type': 'boolean',
#    'values': [{'id': '242085',
#      'name': 'Es un producto hipoalergénico',
#      'results': 2352}]},
#   {'id': 'IS_PARABENS_FREE',
#    'name': 'Otras características',
#    'type': 'boolean',
#    'values': [{'id': '242085',
#      'name': 'Es libre de parabenos',
#      'results': 1460}]},
#   {'id': 'IS_WATER_RESISTANT',
#    'name': 'Otras características',
#    'type': 'boolean',
#    'values': [{'id': '242085',
#      'name': 'Es resistente al agua',
#      'results': 2313}]},
#   {'id': 'ITEM_CONDITION',
#    'name': 'Condición',
#    'type': 'STRING',
#    'values': [{'id': '2230284', 'name': 'Nuevo', 'results': 2975}]},
#   {'id': 'MIN_RECOMMENDED_AGE',
#    'name': 'Edad mínima recomendada',
#    'type': 'range',
#    'values': [{'id': '(*-6años)', 'name': 'Menos de 6 años', 'results': 377},
#     {'id': '[6años-15años)', 'name': '6 a 14 años', 'results': 243},
#     {'id': '[15años-*)', 'name': '15 años o más', 'results': 378}]},
#   {'id': 'state',
#    'name': 'Ubicación',
#    'type': 'text',
#    'values': [{'id': 'TUxBUENBUGw3M2E1',
#      'name': 'Capital Federal',
#      'results': 1490},
#     {'id': 'TUxBUEdSQWU4ZDkz', 'name': 'Bs.As. G.B.A. Norte', 'results': 580},
#     {'id': 'TUxBUEdSQWVmNTVm', 'name': 'Bs.As. G.B.A. Oeste', 'results': 331},
#     {'id': 'TUxBUEdSQXJlMDNm', 'name': 'Bs.As. G.B.A. Sur', 'results': 253},
#     {'id': 'TUxBUENPUmFkZGIw', 'name': 'Córdoba', 'results': 214},
#     {'id': 'TUxBUFNBTmU5Nzk2', 'name': 'Santa Fe', 'results': 41},
#     {'id': 'TUxBUFpPTmFpbnRl', 'name': 'Buenos Aires Interior', 'results': 40},
#     {'id': 'TUxBUENPUnM5MjI0', 'name': 'Corrientes', 'results': 23},
#     {'id': 'TUxBUFNBTGFjMTJi', 'name': 'Salta', 'results': 12},
#     {'id': 'TUxBUENPU2ExMmFkMw',
#      'name': 'Bs.As. Costa Atlántica',
#      'results': 9},
#     {'id': 'TUxBUFLNT29iZmZm', 'name': 'Río Negro', 'results': 5},
#     {'id': 'TUxBUEVOVHMzNTdm', 'name': 'Entre Ríos', 'results': 4},
#     {'id': 'TUxBUFRVQ244NmM3', 'name': 'Tucumán', 'results': 3},
#     {'id': 'TUxBUExBWmE1OWMy', 'name': 'La Pampa', 'results': 2},
#     {'id': 'TUxBUFNBTm5lYjU4', 'name': 'San Juan', 'results': 2},
#     {'id': 'TUxBUFNBTno3ZmY5', 'name': 'Santa Cruz', 'results': 2},
#     {'id': 'TUxBUE1FTmE5OWQ4', 'name': 'Mendoza', 'results': 1},
#     {'id': 'TUxBUEZPUmE1OTk5', 'name': 'Formosa', 'results': 1},
#     {'id': 'TUxBUEpVSnk3YmUz', 'name': 'Jujuy', 'results': 1},
#     {'id': 'TUxBUFNBTm9lOTlk', 'name': 'Santiago del Estero', 'results': 1}]},
#   {'id': 'NET_WEIGHT',
#    'name': 'Peso neto',
#    'type': 'range',
#    'values': [{'id': '(*-50g]', 'name': '50 g o menos', 'results': 715},
#     {'id': '[50g-60g]', 'name': '50 a 60 g', 'results': 645},
#     {'id': '[60g-150g]', 'name': '60 a 150 g', 'results': 513},
#     {'id': '[150g-*)', 'name': '150 g o más', 'results': 645}]},
#   {'id': 'SALE_FORMAT',
#    'name': 'Formato de venta',
#    'type': 'STRING',
#    'values': [{'id': '1359391', 'name': 'Unidad', 'results': 2387},
#     {'id': '1359392', 'name': 'Pack', 'results': 145}]},
#   {'id': 'SUNSCREEN_FORMAT',
#    'name': 'Formato',
#    'type': 'STRING',
#    'values': [{'id': '7176522', 'name': 'Crema', 'results': 977},
#     {'id': '8920501', 'name': 'Emulsión', 'results': 377},
#     {'id': '7176524', 'name': 'Spray', 'results': 356},
#     {'id': '8694330', 'name': 'Fluído', 'results': 229},
#     {'id': '8694332', 'name': 'Pomo', 'results': 136},
#     {'id': '13233638', 'name': 'Gel crema', 'results': 125},
#     {'id': '8920500', 'name': 'Spray continuo', 'results': 113},
#     {'id': '8694324', 'name': 'Bruma', 'results': 39},
#     {'id': '7176523', 'name': 'Gel', 'results': 39},
#     {'id': '8694331', 'name': 'Loción', 'results': 34},
#     {'id': '8712212', 'name': 'Barra', 'results': 26},
#     {'id': '8694337', 'name': 'Gel-Crema', 'results': 23},
#     {'id': '8694336', 'name': 'Crema-Gel', 'results': 19},
#     {'id': '8694328', 'name': 'Aerosol', 'results': 16},
#     {'id': '8694334', 'name': 'Shaka-Shaka', 'results': 9},
#     {'id': '8782201', 'name': 'Aceite', 'results': 7},
#     {'id': '8709795', 'name': 'Tubo dosificador', 'results': 7},
#     {'id': '8712214', 'name': 'Polvo', 'results': 5},
#     {'id': '8694333', 'name': 'Compacto', 'results': 5},
#     {'id': '8709798', 'name': 'Tubo', 'results': 4},
#     {'id': '8694326', 'name': 'Stick', 'results': 4},
#     {'id': '8868334', 'name': 'Lápiz labial', 'results': 3},
#     {'id': '8694329', 'name': 'Sérum', 'results': 3},
#     {'id': '9162730', 'name': 'Toque seco', 'results': 2},
#     {'id': '8694327', 'name': 'Mousse', 'results': 1},
#     {'id': '8694322', 'name': 'Tic-Tac', 'results': 1}]},
#   {'id': 'UNITS_PER_PACK',
#    'name': 'Unidades por pack',
#    'type': 'range',
#    'values': [{'id': '[1-1]', 'name': 'Por unidad', 'results': 2369},
#     {'id': '[2-3)', 'name': '2 unidades', 'results': 60},
#     {'id': '[3-*)', 'name': '3 unidades o más', 'results': 67}]},
#   {'id': 'product',
#    'name': 'Producto',
#    'type': 'text',
#    'values': [{'id': 'MLA16048240',
#      'name': 'Dermaglós Solar FPS 40 Emulsión',
#      'results': 52},
#     {'id': 'MLA16048268',
#      'name': 'Dermaglós Solar FPS 50 Emulsión',
#      'results': 52},
#     {'id': 'MLA16048248',
#      'name': 'Eucerin Oil Control Toque Seco Gel crema',
#      'results': 46},
#     {'id': 'MLA16048239',
#      'name': 'Protector Solar Dermaglós FPS40 Emulsión x250ml',
#      'results': 41},
#     {'id': 'MLA16048420', 'name': 'Dermaglós FPS 30 Emulsión', 'results': 39},
#     {'id': 'MLA16048315',
#      'name': 'Protector solar Dermaglós FPS 50 FPS 50 en emulsión de 250 mL',
#      'results': 36},
#     {'id': 'MLA16048550',
#      'name': 'Protector solar Dermaglós FPS 50 FPS 50 Con Color Tono Claro en crema de 50 g',
#      'results': 32},
#     {'id': 'MLA16048551',
#      'name': 'Dermaglós FPS 50 Con Color Tono Claro Crema',
#      'results': 32},
#     {'id': 'MLA16048265',
#      'name': 'Protector Solar Dermaglós FPS50 Spray Continuo x170ml',
#      'results': 31},
#     {'id': 'MLA16048266',
#      'name': 'Dermaglós FPS 50 Invisible Spray continuo',
#      'results': 31},
#     {'id': 'MLA16048320',
#      'name': 'Protector Solar Dermaglós FPS65 Crema x 90g',
#      'results': 28},
#     {'id': 'MLA16048321',
#      'name': 'Dermaglós Solar FPS 65 Crema',
#      'results': 28},
#     {'id': 'MLA16048490',
#      'name': 'Protector solar Dermaglós FPS 30 FPS 30 Efecto Seco en crema de 180 g',
#      'results': 28},
#     {'id': 'MLA16048491',
#      'name': 'Dermaglós FPS 30 Efecto Seco Crema',
#      'results': 28},
#     {'id': 'MLA16048375',
#      'name': 'Dermaglós Niños FPS 50 Emulsión',
#      'results': 27},
#     {'id': 'MLA16048398',
#      'name': 'Protector solar Dermaglós FPS 40 FPS 40 en spray continuo de 170 mL',
#      'results': 27},
#     {'id': 'MLA16048399',
#      'name': 'Dermaglós FPS 40 Spray continuo',
#      'results': 27},
#     {'id': 'MLA16048374',
#      'name': 'Protector solar Dermaglós Niños FPS 50 FPS 50 en emulsión de 180 mL',
#      'results': 26},
#     {'id': 'MLA16048421',
#      'name': 'Dermaglós FPS 30 Emulsión - 30 - 250 mL',
#      'results': 25},
#     {'id': 'MLA16048278',
#      'name': 'Protector solar Dermaglós FPS 80 FPS 80 en crema de 90 g',
#      'results': 24},
#     {'id': 'MLA16048279', 'name': 'Dermaglós FPS 80 Crema', 'results': 24},
#     {'id': 'MLA19504443', 'name': 'Dermaglós Solar Crema', 'results': 23},
#     {'id': 'MLA25903289',
#      'name': 'Eucerin Protector Solar Facial Hydro Fluid Fps50+ 50 Ml Eucerin PROTECCION SOLAR Hydro Fluid',
#      'results': 23},
#     {'id': 'MLA25903292',
#      'name': 'Eucerin Protector Solar Facial Hydro Fluid Fps50+ 50 Ml',
#      'results': 23},
#     {'id': 'MLA16048338',
#      'name': 'Eucerin Sun Protector Solar Fps 50 Pigment Control Fluid X50',
#      'results': 22},
#     {'id': 'MLA16048339',
#      'name': 'Eucerin Pigment Control Sun Fluído',
#      'results': 22},
#     {'id': 'MLA19504472',
#      'name': 'Dermaglos Facial Fps50 Efecto Seco Invisible X 50 Gr',
#      'results': 22},
#     {'id': 'MLA16189495',
#      'name': 'Protector solar Dermaglós FPS 50 FPS 50 Con Color Tono Medio en crema de 50 g',
#      'results': 21},
#     {'id': 'MLA16189496',
#      'name': 'Dermaglós FPS 50 Con Color Tono Medio Crema',
#      'results': 21},
#     {'id': 'MLA19509037',
#      'name': 'La Roche Posay Anthelios Age Correct Fps50 Sin Color 50ml La Roche-Posay Anthelios Age Correct Crema',
#      'results': 21},
#     {'id': 'MLA19509065',
#      'name': 'La Roche Posay Anthelios Age Correct Fps50 Sin Color 50ml',
#      'results': 21},
#     {'id': 'MLA19638903',
#      'name': 'Anthelios Uvmune 400 Fluido Invisible50+ La Roche-posay 50ml La Roche-Posay Anthelios',
#      'results': 21},
#     {'id': 'MLA19638909',
#      'name': 'Anthelios Uvmune 400 Fluido Invisible50+ La Roche-posay 50ml',
#      'results': 21},
#     {'id': 'MLA16048424',
#      'name': 'Protector Solar Color Efecto Mate Anthelios Fps 50+ La Roche',
#      'results': 19},
#     {'id': 'MLA16048425',
#      'name': 'La Roche-Posay Anthelios XL Toque Seco con Color Pomo',
#      'results': 19},
#     {'id': 'MLA19504447',
#      'name': 'Isdin Protector Solar Age Repair Fusion Water Fps50+ X 50 Ml Isdin Foto Ultra',
#      'results': 19},
#     {'id': 'MLA19504484',
#      'name': 'Isdin Protector Solar Age Repair Fusion Water Fps50+ X 50 Ml',
#      'results': 19},
#     {'id': 'MLA19509038',
#      'name': 'Eucerin Sun Fps 50 Oil Control Claro Toque Seco Facial X50ml Eucerin Oil Control Crema',
#      'results': 18},
#     {'id': 'MLA19509067',
#      'name': 'Eucerin Sun Fps 50 Oil Control Claro Toque Seco Facial X50ml',
#      'results': 18},
#     {'id': 'MLA19531201',
#      'name': 'Protector Solar Isdin Color Fps\xa050 En Crema 1 Unidad De 50\xa0ml 50\xa0g Isdin Color Crema',
#      'results': 18},
#     {'id': 'MLA19531221',
#      'name': 'Protector Solar Isdin Color Fps\xa050 En Crema 1 Unidad De 50\xa0ml 50\xa0g',
#      'results': 18},
#     {'id': 'MLA16048275',
#      'name': 'Protector solar Eucerin Oil Control FPS 50 Toque Seco en gel crema de 50 mL',
#      'results': 17},
#     {'id': 'MLA16048231',
#      'name': 'Dermaglós Niños FPS 50 Spray continuo - 50 - 170 mL',
#      'results': 16},
#     {'id': 'MLA16048232',
#      'name': 'Dermaglós Niños FPS 50 Spray continuo',
#      'results': 16},
#     {'id': 'MLA16048352',
#      'name': 'Protector Solar Efecto Mate Pieles Grasas Anthelios Fps 50+',
#      'results': 16},
#     {'id': 'MLA16048353',
#      'name': 'La Roche-Posay Anthelios XL Toque Seco Pomo',
#      'results': 16},
#     {'id': 'MLA19638907',
#      'name': 'Fotocorrector La Roche-Posay anthelios oil correct 50 + spf 50ml para piel grasa anti-imperfecciones La Roche-Posay Anthelios Oil Correct Gel crema',
#      'results': 16},
#     {'id': 'MLA19638913',
#      'name': 'Anthelios Oil Correct Anti Acné Para Piel Grasa Fps 50 50 Ml',
#      'results': 16},
#     {'id': 'MLA16048528',
#      'name': 'Protector Solar Bruma Rostro Anthelios Fps 50+ La Roche Posa',
#      'results': 14},
#     {'id': 'MLA16048529',
#      'name': 'La Roche-Posay Anthelios Bruma de Rostro Bruma',
#      'results': 14}]}],
#  'pads_info': {'tracelog': ['mclics_off_cause=limit_zero;no_d2id;mclics_off']}}

# %%
# Para chequear haber hecho bien la busqueda inspeccionamos dentro del primer elemento
# del diccionario, en la variable 'results' y pedimos que nos brinde el título
data['results'][0]['title']

# Con el resultado vemos que hicimos bien la búsqueda
# Out:
# 'Protector Solar Eucerin Oil Control Fps 50 Toque Seco En Gel Crema De 50 Ml'

# %% [markdown]
# #### Ejercicio 2
# Guarden los precios de los ítems obtenidos en un dataframe y calculen el precio promedio, el mínimo y el máximo.

# %%
# Importamos el módulo que requeriremos para hacer el dataframe y el histograma
import pandas as pd

# %%
# Creamos un dataframe que contiene dos columnas, una con el título de los productos y otra con los precios
precios_df = pd.DataFrame(columns=['Title', 'Price'])

# Armamos un loop que permitirá ir llenando el dataframe generado previamente con los productos obtenidos
for result in data['results']:
    precios_df = precios_df.append({'Title': result['title'], 'Price': result['price']}, ignore_index=True)
    
# Observamos los resultados. Guardamos el nombre del producto para poder verificar que efectivamente sea un protector solar.
print(precios_df)
# Out:
#                                                 Title     Price
# 0   Protector Solar Eucerin Oil Control Fps 50 Toq...     11691
# 1   Dermaglos Facial Fps50 Efecto Seco Invisible X...      8846
# 2   Protector Solar Dermaglós Fps 30 Fps 30 En Emu...   9883.65
# 3   Isdin Protector Solar Age Repair Fusion Water ...     19649
# 4   Umbrella Intelligent Protector Solar Spf 99 50grs  13490.18
# 5   Protector Solar Dermaglós Fps 50 Fps 50 En Emu...      7145
# 6   Isdin Fotoprotector Spf50+ Fusion Water Toque ...     14701
# 7   Anthelios Uvmune 400 Fluido Invisible50+ La Ro...     12232
# 8   Fotoprotector Isdin Spf 50+ Gel Crema Protecto...     20487
# 9   Isdin Foto Ultra Active Unify Fusion Fluid Col...   23722.2
# 10  Fotoprotector Isdin Pediatrics Fps 50+ Fusion ...  17486.61
# 11  Vansame Solar Crema Fps 50+ Pieles Extremadame...     15900
# 12  Protector Solar Dermaglós Fps50 Spray Continuo...      8340
# 13  Protector Solar Facial Eucerin Sun Fps 50+ Ton...     12524
# 14  Fotoprotector Isdin Fusion Water Color Ligth  ...  16538.96
# 15  Protector Solar Color Efecto Mate Anthelios Fp...     11017
# 16      Dermaglós Solar Fps 50 Emulsión - 50 - 380 Ml     11819
# 17    Protector Solar Dermaglós Fps40 Emulsión X250ml      7157
# 18  Protector Solar La Roche-posay Anthelios Xl Fp...     12227
# 19  Protector Solar Dermaglós Fps 40 Fps 40 Efecto...      9190
# 20            Dermaglós Fps 30 Emulsión - 30 - 250 Ml      6862
# 21  Protector Solar Bronceador 8fps 250ml Cocoa Be...      4174
# 22  Protector Solar Dermaglós Fps 80 Fps 80 En Cre...      9790
# 23     Protector Solar Dermaglós Fps50 Emulsión X50ml   2530.06
# 24  Rayito De Sol Bioactive Facial Protector Solar...      5698
# 25  Eucerin Sun Fps 50 Oil Control Claro Toque Sec...     12524
# 26  Cicatricure Protector Solar Fps 50 Antiage X 5...    5214.8
# 27      Exel Pantalla Fotoprotectora Fps 60 Con Color      7300
# 28  Caviahue Protector Solar Fps 50+  Gluten Free ...      7725
# 29                  Cepage Filtres Fluide 50+ X 50 Ml    8612.2
# 30  Caviahue Protector Solar Fps 50 Familiar Aeros...      5680
# 31  Protector Solar Dermaglós Fps 30 Fps 30 Efecto...      7284
# 32  Eucerin Sun Fps50+ Gel-crema Corporal Toque Se...     11427
# 33        Protector Solar Dermaglós Fps65 Crema X 90g      7937
# 34  Eucerin Protector Solar Facial Hydro Fluid Fps...     11542
# 35  Anthelios Oil Correct Anti Acné Para Piel Gras...     14568
# 36  Protector Solar Isdin Fusion Fluid Fps 50 1 Un...     14769
# 37  Lda Maprosol 50+ Emulsión Fluida Color 140ml P...  11634.91
# 38  Dermaglós Protector Solar Fps 80 Crema Pieles ...     10882
# 39  Isdin Set Protector Solar Fusion Water + Wet S...     41832
# 40  Dermaglos Linea Solar Fps 50 Aerosol Invisible...  11706.24
# 41  Isdin Eryfotona Spf99 Fluid Protector Solar Pi...     28000
# 42  La Roche Posay Anthelios Protector Solar Fps50...     12441
# 43  Bagovit Solar Family Care Protección Solar Fps...      7647
# 44  Fotosol Ultra Protector Solar Fps50 Fp Uva21 C...      4759
# 45  Protector Solar Lidherma Fps 40 En Crema 1 Uni...   6653.88
# 46  Fotoprotector Isdin Spf 50+ Gel Crema Dry Touc...     16240
# 47  Protector Solar Avène Fps 50 Crema En Tubo Dos...      9336
# 48  Protector Solar Facial Eucerin Sun Fps 50+ Ton...     12524
# 49  Protector Solar Eucerin Sun Crema Gel Fps50 X ...     15327
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4700\3004186628.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': result['title'], 'Price': result['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4700\3004186628.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': result['title'], 'Price': result['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4700\3004186628.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': result['title'], 'Price': result['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4700\3004186628.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': result['title'], 'Price': result['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4700\3004186628.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': result['title'], 'Price': result['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4700\3004186628.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': result['title'], 'Price': result['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4700\3004186628.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': result['title'], 'Price': result['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4700\3004186628.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': result['title'], 'Price': result['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4700\3004186628.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': result['title'], 'Price': result['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4700\3004186628.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': result['title'], 'Price': result['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4700\3004186628.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': result['title'], 'Price': result['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4700\3004186628.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': result['title'], 'Price': result['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4700\3004186628.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': result['title'], 'Price': result['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4700\3004186628.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': result['title'], 'Price': result['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4700\3004186628.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': result['title'], 'Price': result['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4700\3004186628.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': result['title'], 'Price': result['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4700\3004186628.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': result['title'], 'Price': result['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4700\3004186628.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': result['title'], 'Price': result['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4700\3004186628.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': result['title'], 'Price': result['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4700\3004186628.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': result['title'], 'Price': result['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4700\3004186628.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': result['title'], 'Price': result['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4700\3004186628.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': result['title'], 'Price': result['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4700\3004186628.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': result['title'], 'Price': result['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4700\3004186628.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': result['title'], 'Price': result['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4700\3004186628.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': result['title'], 'Price': result['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4700\3004186628.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': result['title'], 'Price': result['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4700\3004186628.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': result['title'], 'Price': result['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4700\3004186628.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': result['title'], 'Price': result['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4700\3004186628.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': result['title'], 'Price': result['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4700\3004186628.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': result['title'], 'Price': result['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4700\3004186628.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': result['title'], 'Price': result['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4700\3004186628.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': result['title'], 'Price': result['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4700\3004186628.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': result['title'], 'Price': result['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4700\3004186628.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': result['title'], 'Price': result['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4700\3004186628.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': result['title'], 'Price': result['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4700\3004186628.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': result['title'], 'Price': result['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4700\3004186628.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': result['title'], 'Price': result['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4700\3004186628.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': result['title'], 'Price': result['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4700\3004186628.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': result['title'], 'Price': result['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4700\3004186628.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': result['title'], 'Price': result['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4700\3004186628.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': result['title'], 'Price': result['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4700\3004186628.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': result['title'], 'Price': result['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4700\3004186628.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': result['title'], 'Price': result['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4700\3004186628.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': result['title'], 'Price': result['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4700\3004186628.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': result['title'], 'Price': result['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4700\3004186628.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': result['title'], 'Price': result['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4700\3004186628.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': result['title'], 'Price': result['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4700\3004186628.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': result['title'], 'Price': result['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4700\3004186628.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': result['title'], 'Price': result['price']}, ignore_index=True)
# C:\Users\mateo\AppData\Local\Temp\ipykernel_4700\3004186628.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   precios_df = precios_df.append({'Title': result['title'], 'Price': result['price']}, ignore_index=True)

# %%
# Calculamos el precio máximo, mínimo y promedio
precio_maximo = precios_df['Price'].max()
precio_minimo = precios_df['Price'].min()
precio_promedio = precios_df['Price'].mean()

# Observamos los resultados
print(f"Precio máximo: {precio_maximo}")
print(f"Precio mínimo: {precio_minimo}")
print(f"Precio promedio: {precio_promedio}")
# Out:
# Precio máximo: 41832
# Precio mínimo: 2530.06
# Precio promedio: 11933.333799999999

# %% [markdown]
# #### Ejercicio 3
# Armen un histograma de los precios. ¿Ven algún <i>outlier<i>?
# Nota: pueden usar la librería de Matplotlib o la de Pandas.

# %%
# Armamos un histograma de los precios
plt.hist(precios_df['Price'],bins='auto', edgecolor='k') 
# Matplotlib utiliza el número de bins óptimo según la regla de Freedman-Diaconis. 

# Brindamos referencias para los ejes
plt.xlabel('Precio')
plt.ylabel('Frecuencia')
plt.title('Histograma de Precios - Protector Solar')
sample_size = len(precios_df)
plt.text(0.9, 0.9, f'N= {sample_size}',transform=plt.gca().transAxes,
         fontsize=10) 
# Mencionamos el número de observaciones. Los dos primeros parámetros determinan la ubicación 
# del texto en términos de coordenadas.
# EL valor de transform nos dice que las coordenadas son relativas al tamaño de los ejes. 
# El tercer parámetro indica el texto y el último, el tamaño de letra.

# Ejecutamos el gráfico para que nos lo muestre
plt.show()

# %%
#  Usamos la regla del IQR para identificar outliers
Q1 = precios_df['Price'].quantile(0.25)
Q3 = precios_df['Price'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = precios_df[(precios_df['Price'] < lower_bound) | (precios_df['Price'] > upper_bound)]
n_outliers=len(outliers)
print(n_outliers) # Aquí veremos la cantidad de outliers.


# Notar que si se modifica la página o los precios, puede variar el resultado de los outliers.
# Al momento donde corrimos el código tenemos 2 outliers con la regla elegida (IQR)
# Out:
# 2
